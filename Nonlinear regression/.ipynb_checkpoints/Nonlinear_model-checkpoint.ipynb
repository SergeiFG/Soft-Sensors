# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import torch
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
import sys
sys.path.append("..")

import Essentials

# %%
data_archive = np.load('..\Data_Average.npz', allow_pickle=True)

# %%
def prepare_Y(y):
    timestamp = y[:, 1]   
    y = y[:, 0].reshape(len(y), 1)
    y = y.astype(np.float64)

    return y, timestamp

# %%
X_test_1 = data_archive['X_test_1']
X_train_1 = data_archive['X_train_1']

X_test_2 = data_archive['X_test_2']
X_train_2 = data_archive['X_train_2']

X_test_3 = data_archive['X_test_3']
X_train_3 = data_archive['X_train_3']

Y_test_1, timestamp_test_1 = prepare_Y(data_archive['Y_test_1'])
Y_train_1, timestamp_train_1 = prepare_Y(data_archive['Y_train_1'])

Y_test_2, timestamp_test_2 = prepare_Y(data_archive['Y_test_2'])
Y_train_2, timestamp_train_2 = prepare_Y(data_archive['Y_train_2'])

Y_test_3, timestamp_test_3 = prepare_Y(data_archive['Y_test_3'])
Y_train_3, timestamp_train_3 = prepare_Y(data_archive['Y_train_3'])

# %%
df_X1 = pd.read_csv(r'..\raw_X1.csv', index_col=0)
df_X2 = pd.read_csv(r'..\raw_X2.csv', index_col=0)
df_X3 = pd.read_csv(r'..\raw_X3.csv', index_col=0)

# %%
labels_1 = list(df_X1.columns)[:-1]
labels_2 = list(df_X1.columns)[:-1]
labels_3 = list(df_X1.columns)[:-1]

# %%
# df_np = df.to_numpy()
# x_raw = df_np[:, :-1]
# y_raw = df_np[:, -1].reshape(-1, 1)

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(x_raw, y_raw, test_size=0.25, shuffle=True)

# %%
x_scaler = StandardScaler()
y_scaler = StandardScaler()

x_scaler.fit(X_train_1)
y_scaler.fit(Y_train_1)
# Out:
# StandardScaler()

# %%
X_train_norm = x_scaler.transform(X_train_1)
Y_train_norm = y_scaler.transform(Y_train_1)

X_test_norm = x_scaler.transform(X_test_1)
Y_test_norm = y_scaler.transform(Y_test_1)

# %%
X_test_norm.shape
# Out:
# (74, 96)

# %%
class RegressionModel(torch.nn.Module):
    def __init__(self, metric, lr, layers=[]):
        super().__init__()
        self.layers = torch.nn.ModuleList(layers)
        self.metric = metric
        self.lr = lr
        
    def add_layer(self, layer):
        self.layers.append(layer)

    def forward(self, x_dict):
        res = torch.zeros(list(x_dict.values())[0].shape)
        for layer in self.layers:
            res = res + layer(x_dict)
        return res

    def disable_training(self):
        for layer in self.layers[1:]:
            layer.disable_training(self.lr)

    def get_metric(self, x_dict, y_true):
        y_pred = self.forward(x_dict)
        return self.metric(y_true, y_pred.detach())

    def get_layers(self):
        return list(self.layers)

    def __str__(self):
        string = ''
        for layer in self.layers:
            string = string + ' + ' + str(layer.lr_coeff) + '*' + layer.__str__()
        return 'Y = ' + string[3:]

# %%
class RegressionLayer(torch.nn.Module):
    def __init__(self, torch_layers: list, input_layer, data_from_dict = False):
        super().__init__()
        self.torch_layers = torch.nn.Sequential(*torch_layers)
        self.input_layer = input_layer
        self.data_from_dict = data_from_dict
        self.lr_coeff = 1

    def forward(self, x_dict):
        if self.data_from_dict:
            x_data = x_dict[self]                        
        else:
            x_data = self.input_layer(x_dict)
        if isinstance(self.torch_layers[0], multi_layer):
            return self.torch_layers([x_data, x_dict])
        return self.lr_coeff * self.torch_layers(x_data)

    def __str__(self):
        input_string = self.input_layer.__str__()
        for torch_layer in self.torch_layers:
            torch_layer.set_input(input_string)
            res_string = torch_layer.__str__()
            input_string = res_string
        
        return res_string

    def disable_training(self, lr):
        self.lr_coeff = lr
        for torch_layer in self.torch_layers:
            for param in torch_layer.parameters():
                param.requires_grad = False

# %%
class TorchLayer(torch.nn.Module):
    
    size = 0
    ndigs = 2

    def __init__(self):
        super().__init__()
        self.weights = torch.nn.Parameter(torch.empty(self.size))
        torch.nn.init.normal_(self.weights) 
        self.input_layer = None

    def forward(self, x_data):
        pass

    def set_input(self, input_layer):
        self.input_layer = input_layer

# %%
def round2(weight, ndigits):
    return round(weight.detach().item(), ndigits)

# %%
class linear_layer(TorchLayer):
       
    size = 1

    def forward(self, x):
        return self.weights[0]*x

    def __str__(self):
        return f"({round2(self.weights[0], self.ndigs)}) * ({self.input_layer})"  


class exp_layer(TorchLayer):

    size = 2

    def forward(self, x):
        return self.weights[1] * (torch.exp(self.weights[0]*x) - 1)

    def __str__(self):
        return f"({round2(self.weights[1], self.ndigs)}) * (exp({round2(self.weights[0], self.ndigs)} * ({self.input_layer})) - 1)"


class log_layer(TorchLayer):
        
    size = 3

    def forward(self, x):
        return self.weights[2] * torch.log(torch.abs(self.weights[1]*x + self.weights[0]) + 1)

    def __str__(self):
        return f"({round2(self.weights[2], self.ndigs)}) * ln(1 + abs({round2(self.weights[0], self.ndigs)} + ({round2(self.weights[1], self.ndigs)}) * ({self.input_layer})))"    


class start_layer(TorchLayer):
    
    size = 0

    def forward(self, x):
        return x

    def __str__(self):
        return f"{self.input_layer}"  


class const_layer(TorchLayer):
    
    size = 1

    def forward(self, x):
        return self.weights[0] * torch.ones(x.shape)

    def __str__(self):
        return f"({round2(self.weights[0], self.ndigs)})"  


class ReLU_layer(TorchLayer):
        
    size = 3

    def __init__(self):
        super().__init__()
        self.relu = torch.nn.ReLU()

    def forward(self, x):
        tmp = self.weights[1] + x*self.weights[0]
        return self.weights[2] * self.relu(tmp)

    def __str__(self):
        return f"({round2(self.weights[2], self.ndigs)}) * max(0, ({round2(self.weights[0], self.ndigs)}) * ({self.input_layer}) + ({round2(self.weights[1], self.ndigs)})"    


class Tanh_layer(TorchLayer):
        
    size = 3

    def __init__(self):
        super().__init__()
        self.tanh = torch.nn.Tanh()

    def forward(self, x):
        tmp = self.weights[1] + x*self.weights[0]
        return self.weights[2] * self.tanh(tmp)

    def __str__(self):
        return f"({round2(self.weights[2], self.ndigs)}) * tanh(({round2(self.weights[0], self.ndigs)}) * ({self.input_layer}) + ({round2(self.weights[1], self.ndigs)})"  


class multi_layer(TorchLayer):
        
    size = 1

    def __init__(self, second_layer):
        super().__init__()
        self.second_x = second_layer

    def forward(self, x):
        return self.weights[0] * x[0] * self.second_x(x[1])

    def __str__(self):
        return f"({round2(self.weights[0], self.ndigs)}) * ({self.input_layer}) * ({self.second_x.__str__()})"  


class abs_layer(TorchLayer):
        
    size = 1

    def forward(self, x):
        return self.weights[0] * torch.abs(x)

    def __str__(self):
        return f"({round2(self.weights[0], self.ndigs)}) * abs({self.input_layer})"  


class pow_layer(TorchLayer):
        
    size = 2

    def forward(self, x):
        return self.weights[1] * torch.pow(torch.abs(x), self.weights[0])

    def __str__(self):
        return f"({round2(self.weights[1], self.ndigs)}) * (abs({self.input_layer}) ** ({round2(self.weights[0], self.ndigs)}))"

# %%
def train(model, X, Y, epoch_num=1000, verbose=True):    
    optimizer = torch.optim.Adam(model.parameters(), lr=0.005)

    for i in range(epoch_num):
        optimizer.zero_grad()
        Y_pred = model(X)
        loss = criterion(Y_pred, Y.squeeze())
        loss.backward()
        optimizer.step()
        if verbose:
            print(loss.item())

# %%
labels_x = [RegressionLayer([start_layer()], label, data_from_dict=True) for label in labels_1]
c_label = RegressionLayer([const_layer()], 'const', data_from_dict=True)
labels_x.append(c_label)

vectors_x_train = [torch.tensor(col, dtype=torch.float32) for col in X_train_norm.T]
vectors_x_train.append(torch.ones(vectors_x_train[0].shape))
vectors_x_test = [torch.tensor(col, dtype=torch.float32) for col in X_test_norm.T]
vectors_x_test.append(torch.ones(vectors_x_test[0].shape))

# %%
x_train_model = {key: value for key, value in zip(labels_x, vectors_x_train)}
y_train_model = torch.tensor(Y_train_norm, dtype=torch.float32)

x_test_model = {key: value for key, value in zip(labels_x, vectors_x_test)}
y_test_model = torch.tensor(Y_test_norm, dtype=torch.float32)

# %%
possible_layers = [linear_layer, exp_layer, log_layer, ReLU_layer, Tanh_layer, abs_layer, pow_layer]
start_layers = labels_x[:-1]
comb_layers = [multi_layer]

verbose = False
verbose2 = True

x1 = x_train_model
y1 = y_train_model

x2 = x_test_model
y2 = y_test_model

lr = 0.5
max_layers = 1

Model = RegressionModel(r2_score, lr)
Model.add_layer(RegressionLayer([const_layer()], c_label))
criterion = torch.nn.MSELoss()
train(Model, x1, y1, epoch_num=1000, verbose=verbose)
Model.disable_training()


model_layers = Model.get_layers()



# iterate over max_layers
for i in range(max_layers):
    best_layers = None
    best_step_score = Model.get_metric(x1, y1)

    for prev_layer in (start_layers + model_layers):
        if isinstance(prev_layer.torch_layers[0], const_layer):
            continue
       
        for layer in (comb_layers + possible_layers):

            if layer in comb_layers:
                for second_layer in (start_layers + model_layers):
                    if isinstance(second_layer.torch_layers[0], const_layer):
                        continue
                    step_layers = Model.get_layers()
                    step_layers.append(RegressionLayer([layer(second_layer)], prev_layer))
                    if verbose2:
                        print(f"Testing layer {layer.__name__} for {prev_layer.__str__()} and {second_layer.__str__()}")
                        
                    step_model = RegressionModel(r2_score, lr, step_layers)
                    train(step_model, x1, y1, epoch_num=1000, verbose=verbose)
                    step_score = step_model.get_metric(x1, y1)
                    if verbose2:
                        print(f'Got metric value {step_score}')
        
                    if step_score > best_step_score:
                        best_step_score = step_score
                        best_layers = step_layers
                        
            else:
                step_layers = Model.get_layers()
                step_layers.append(RegressionLayer([layer()], prev_layer))
                if verbose2:
                    print(f"Testing layer {layer.__name__} for {prev_layer.__str__()}")          
                   
                step_model = RegressionModel(r2_score, lr, step_layers)
                train(step_model, x1, y1, epoch_num=1000, verbose=verbose)
                step_score = step_model.get_metric(x1, y1)
                if verbose2:
                    print(f'Got metric value {step_score}')
    
                if step_score > best_step_score:
                    best_step_score = step_score
                    best_layers = step_layers
            

    print(f"Done layer {i+1} \n")

    if best_layers is None:
        print('No better layers')
        break

    if best_step_score < 1.01*Model.get_metric(x1, y1):
        print("Weak increase")
        break

    Model = RegressionModel(r2_score, lr, best_layers)
    model_layers = Model.get_layers()
    print("New model: \n")
    print(Model, '\n')
    print(f'New best score {Model.get_metric(x1, y1)} \n')
    print(f'New score on Test {Model.get_metric(x2, y2)} \n')
    print('-------------------------------------------------------------------------------------------------------------------------------')
    Model.disable_training()
# Out:
# Testing layer multi_layer for Расход бензина ККР на установку and Расход бензина ККР на установку
# Got metric value 0.35743371520580336
# Testing layer multi_layer for Расход бензина ККР на установку and Расход нафты ККР на установку
# Got metric value 0.1563899812056211
# Testing layer multi_layer for Расход бензина ККР на установку and Расход бензина на рециркуляцию от Е-1205
# Got metric value 0.23929050172944677
# Testing layer multi_layer for Расход бензина ККР на установку and Температура бензина ККР на установку
# Got metric value 0.04051827492880222
# Testing layer multi_layer for Расход бензина ККР на установку and Расход сырья после Р-1101
# Got metric value 0.333688539049079
# Testing layer multi_layer for Расход бензина ККР на установку and Показатель соотношения водород к углероду
# Got metric value 0.10161429286495693
# Testing layer multi_layer for Расход бензина ККР на установку and Расход водорода на смешение перед Е-1101
# Got metric value 0.20552470104205967
# Testing layer multi_layer for Расход бензина ККР на установку and Температура сырья перед Е-1101
# Got metric value 0.13939025490751977
# Testing layer multi_layer for Расход бензина ККР на установку and Давление сырья перед Е-1101
# Got metric value 0.09818573121596386
# Testing layer multi_layer for Расход бензина ККР на установку and Температура сырья перед Е-1102
# Got metric value 0.383366983047153
# Testing layer multi_layer for Расход бензина ККР на установку and Температура сырья перед Е-1103
# Got metric value 0.13966881364086292
# Testing layer multi_layer for Расход бензина ККР на установку and Давление сырья перед Е-1103
# Got metric value 0.20863365214501106
# Testing layer multi_layer for Расход бензина ККР на установку and Температура сырья после Е-1103
# Got metric value 0.34972312917488335
# Testing layer multi_layer for Расход бензина ККР на установку and Температура ТБ перед Е-1101
# Got metric value 0.3871163963148845
# Testing layer multi_layer for Расход бензина ККР на установку and Давление ТБ перед Е-1101
# Got metric value 0.3805929400236655
# Testing layer multi_layer for Расход бензина ККР на установку and Температура ТБ после Е-1101
# Got metric value 0.3940090262419408
# Testing layer multi_layer for Расход бензина ККР на установку and Температура бензина перед Е-1102
# Got metric value 0.28669706702328257
# Testing layer multi_layer for Расход бензина ККР на установку and Температура бензина после Е-1102
# Got metric value 0.33627785754529194
# Testing layer multi_layer for Расход бензина ККР на установку and Давление бензина после Е-1102
# Got metric value 0.2916088098961924
# Testing layer multi_layer for Расход бензина ККР на установку and Температура пара перед Е-1103
# Got metric value 0.10694994646021971
# Testing layer multi_layer for Расход бензина ККР на установку and Давление пара перед Е-1103
# Got metric value 0.0027928475286603804
# Testing layer multi_layer for Расход бензина ККР на установку and Давление на входе в R-1101
# Got metric value 0.012645861828581517
# Testing layer multi_layer for Расход бензина ККР на установку and Температура на входе в R-1101
# Got metric value 0.35222348867139597
# Testing layer multi_layer for Расход бензина ККР на установку and Перепад давления реактора R-1101
# Got metric value 0.1408159740609919
# Testing layer multi_layer for Расход бензина ККР на установку and Температура на входе в С-1101
# Got metric value 0.32424050558104267
# Testing layer multi_layer for Расход бензина ККР на установку and Давление верха С-1101
# Got metric value 0.13438003254338715
# Testing layer multi_layer for Расход бензина ККР на установку and Температура 2-ой тарелки С-1101
# Got metric value 0.34042361508340324
# Testing layer multi_layer for Расход бензина ККР на установку and Расход ЛБ от С-1101
# Got metric value 0.25795241494918597
# Testing layer multi_layer for Расход бензина ККР на установку and Температура ЛБ от С-1101
# Got metric value 0.180463757302869
# Testing layer multi_layer for Расход бензина ККР на установку and Температура 9-ой тарелки С-1101
# Got metric value 0.001526611561184943
# Testing layer multi_layer for Расход бензина ККР на установку and Температура куба С-1101
# Got metric value 0.022784392478121585
# Testing layer multi_layer for Расход бензина ККР на установку and Уровень куба С-1101
# Got metric value 0.005184871670093849
# Testing layer multi_layer for Расход бензина ККР на установку and Расход ТБ с куба С-1101
# Got metric value 0.3324174760908061
# Testing layer multi_layer for Расход бензина ККР на установку and Расход пара на ребойлеры Е-1105
# Got metric value 0.3584641156922249
# Testing layer multi_layer for Расход бензина ККР на установку and Температура ТБ после ребойлеров Е-1105
# Got metric value 0.052012654392559754
# Testing layer multi_layer for Расход бензина ККР на установку and Давление ЛБ после АВО А-1101
# Got metric value 0.12744127142832762
# Testing layer multi_layer for Расход бензина ККР на установку and Температура ЛБ после АВО А-1101
# Got metric value 0.05292065457916162
# Testing layer multi_layer for Расход бензина ККР на установку and Давление в емкости V-1102
# Got metric value 0.027444543722445758
# Testing layer multi_layer for Расход бензина ККР на установку and Уровень в емкости V-1102
# Got metric value 0.0006504784502298078
# Testing layer multi_layer for Расход бензина ККР на установку and Расход насыщенного газа после V-1102
# Got metric value 0.014813956323480704
# Testing layer multi_layer for Расход бензина ККР на установку and Температура окружающей среды
# Got metric value 0.0640666069738105
# Testing layer multi_layer for Расход бензина ККР на установку and Температура ТБ перед Е-1201А
# Got metric value 0.011057847529548304
# Testing layer multi_layer for Расход бензина ККР на установку and Температура ТБ после Е-1201С перед Е-1201D
# Got metric value 0.3527252845910894
# Testing layer multi_layer for Расход бензина ККР на установку and Температура ТБ после Е-1201D
# Got metric value 0.351445889168871
# Testing layer multi_layer for Расход бензина ККР на установку and Температура ТБ после Е-1201D перед Е-1201C
# Got metric value 0.3790410984477711
# Testing layer multi_layer for Расход бензина ККР на установку and Температура ТБ после Е-1201A
# Got metric value 0.38740638000665695
# Testing layer multi_layer for Расход бензина ККР на установку and Расход ЛБ на орошение С-1101
# Got metric value 0.3358944382570398
# Testing layer multi_layer for Расход бензина ККР на установку and Температура на входе в R-1201
# Got metric value 0.35066598566007356
# Testing layer multi_layer for Расход бензина ККР на установку and Давление на входе в R-1201
# Got metric value 0.41657853449432813
# Testing layer multi_layer for Расход бензина ККР на установку and Перепад давления реактора R-1201
# Got metric value 0.4219968460811172
# Testing layer multi_layer for Расход бензина ККР на установку and Расход квенча реактора R-1201
# Got metric value 0.38293956630269754
# Testing layer multi_layer for Расход бензина ККР на установку and Давление на выходе из R-1201
# Got metric value 0.41222705934513226
# Testing layer multi_layer for Расход бензина ККР на установку and Температура на выходе из R-2101
# Got metric value 0.30655875584878
# Testing layer multi_layer for Расход бензина ККР на установку and Давление на входе в H-1201
# Got metric value 0.4123212182406858
# Testing layer multi_layer for Расход бензина ККР на установку and Температура на входе в H-1201
# Got metric value 0.3542966137045561
# Testing layer multi_layer for Расход бензина ККР на установку and Давление на выходе из H-1201
# Got metric value 0.3762109510017084
# Testing layer multi_layer for Расход бензина ККР на установку and Температура на выходе из H-1201
# Got metric value 0.34335898240789997
# Testing layer multi_layer for Расход бензина ККР на установку and Уровень в емкости V-1201
# Got metric value 0.03397448830982519
# Testing layer multi_layer for Расход бензина ККР на установку and Давление в емкости V-1201
# Got metric value 0.3243220755714339
# Testing layer multi_layer for Расход бензина ККР на установку and Температура в емкости V-1201
# Got metric value 0.33513771211234966
# Testing layer multi_layer for Расход бензина ККР на установку and Расход ТБ из емкости V-1201
# Got metric value 0.3457282521313353
# Testing layer multi_layer for Расход бензина ККР на установку and Температура перед А-1201
# Got metric value 0.34837618872888687
# Testing layer multi_layer for Расход бензина ККР на установку and Температура после А-1201
# Got metric value 0.05360825442734063
# Testing layer multi_layer for Расход бензина ККР на установку and Уровень в емкости V-1202
# Got metric value 0.0811589059364185
# Testing layer multi_layer for Расход бензина ККР на установку and Температура в емкости V-1202
# Got metric value 0.04788405499490467
# Testing layer multi_layer for Расход бензина ККР на установку and Давление верха С-1202
# Got metric value 0.12867210196741508
# Testing layer multi_layer for Расход бензина ККР на установку and Температура верха С-1202
# Got metric value 0.020312113435352885
# Testing layer multi_layer for Расход бензина ККР на установку and Температура питания С-1202
# Got metric value 0.009990081672740292
# Testing layer multi_layer for Расход бензина ККР на установку and Температура С-1202
# Got metric value 0.00730642002531301
# Testing layer multi_layer for Расход бензина ККР на установку and Температура глухой тарелки С-1202
# Got metric value 0.0149887606564868
# Testing layer multi_layer for Расход бензина ККР на установку and Давление С-1202
# Got metric value 0.13616575800112485
# Testing layer multi_layer for Расход бензина ККР на установку and Уровень куба С-1202
# Got metric value 0.2051733024172956
# Testing layer multi_layer for Расход бензина ККР на установку and Температура куба С-1202
# Got metric value 0.021841786641698335
# Testing layer multi_layer for Расход бензина ККР на установку and Расход пара на ребойлер Е-1204
# Got metric value 0.11044578107322833
# Testing layer multi_layer for Расход бензина ККР на установку and Температура пара на ребойлер Е-1204
# Got metric value 0.17527043080882376
# Testing layer multi_layer for Расход бензина ККР на установку and Давление пара на ребойлер Е-1204
# Got metric value 0.004640022758207407
# Testing layer multi_layer for Расход бензина ККР на установку and Температура ТБ после ребойлера Е-1204
# Got metric value 0.011120428635051582
# Testing layer multi_layer for Расход бензина ККР на установку and Возврат ТБ в С-1202 после насосов Р-1204
# Got metric value 0.0029945917258604737
# Testing layer multi_layer for Расход бензина ККР на установку and Расход ТБ после Е-1203
# Got metric value 0.34828929078791615
# Testing layer multi_layer for Расход бензина ККР на установку and Температура ТБ после Е-1203
# Got metric value 0.3762562832218719
# Testing layer multi_layer for Расход бензина ККР на установку and Уровень в емкости V-1205
# Got metric value 0.12432791717086844
# Testing layer multi_layer for Расход бензина ККР на установку and Давление в емкости V-1205
# Got metric value 0.07961230022483146
# Testing layer multi_layer for Расход бензина ККР на установку and Возврат ТБ в V-1205 после насосов Р-1203
# Got metric value 0.04167797754991165
# Testing layer multi_layer for Расход бензина ККР на установку and Расход ТБ из V-1205 после насосов Р-1203
# Got metric value 0.0764372290173102
# Testing layer multi_layer for Расход бензина ККР на установку and Давление ЛБ перед А-1203
# Got metric value 0.015703863662595685
# Testing layer multi_layer for Расход бензина ККР на установку and Температура продукта после А-1203
# Got metric value 0.13521520118935715
# Testing layer multi_layer for Расход бензина ККР на установку and Температура продукта после Е-1205
# Got metric value 0.22063052303510244
# Testing layer multi_layer for Расход бензина ККР на установку and Давление продукта после Е-1205
# Got metric value 0.1993252888044612
# Testing layer multi_layer for Расход бензина ККР на установку and Давление продукта на выходе с установки
# Got metric value 0.29332291117740006
# Testing layer multi_layer for Расход бензина ККР на установку and Расход продукта на выходе с установки
# Got metric value 0.35846348176208687
# Testing layer multi_layer for Расход бензина ККР на установку and Уровень V-1203
# Got metric value 0.003009549533367184
# Testing layer multi_layer for Расход бензина ККР на установку and Температура V-1203
# Got metric value 0.022688424442403154
# Testing layer multi_layer for Расход бензина ККР на установку and Давление V-1203
# Got metric value 0.12687408190516158
# Testing layer multi_layer for Расход бензина ККР на установку and Температура верха С-1201
# Got metric value 0.018253790898042244
# Testing layer multi_layer for Расход бензина ККР на установку and Давление верха С-1201
# Got metric value 0.20361226620446649
# Testing layer multi_layer for Расход бензина ККР на установку and Давление С-1201
# Got metric value 0.14764291718083788
# Testing layer linear_layer for Расход бензина ККР на установку
# Got metric value 0.4763138425157065
# Testing layer exp_layer for Расход бензина ККР на установку
# Got metric value 0.5045389546382846
# Testing layer log_layer for Расход бензина ККР на установку
# Got metric value 0.5086356407395798
# Testing layer ReLU_layer for Расход бензина ККР на установку
# Got metric value 0.47635660913232125
# Testing layer Tanh_layer for Расход бензина ККР на установку
# Got metric value 0.496362554174697
# Testing layer abs_layer for Расход бензина ККР на установку
# Got metric value 0.3304683330212591
# Testing layer pow_layer for Расход бензина ККР на установку
# Got metric value -0.14623218476436972
# Testing layer multi_layer for Расход нафты ККР на установку and Расход бензина ККР на установку
# Got metric value 0.1431922124583236
# Testing layer multi_layer for Расход нафты ККР на установку and Расход нафты ККР на установку
# Got metric value 0.1403859003115684
# Testing layer multi_layer for Расход нафты ККР на установку and Расход бензина на рециркуляцию от Е-1205
# Got metric value 0.0860516648623062
# Testing layer multi_layer for Расход нафты ККР на установку and Температура бензина ККР на установку
# Got metric value 0.3394364787338867
# Testing layer multi_layer for Расход нафты ККР на установку and Расход сырья после Р-1101
# Got metric value 0.117917180750292
# Testing layer multi_layer for Расход нафты ККР на установку and Показатель соотношения водород к углероду
# Got metric value 0.07617110825322859
# Testing layer multi_layer for Расход нафты ККР на установку and Расход водорода на смешение перед Е-1101
# Got metric value 0.004328006221506975
# Testing layer multi_layer for Расход нафты ККР на установку and Температура сырья перед Е-1101
# Got metric value 0.38747285265127573
# Testing layer multi_layer for Расход нафты ККР на установку and Давление сырья перед Е-1101
# Got metric value 0.19292793539268727
# Testing layer multi_layer for Расход нафты ККР на установку and Температура сырья перед Е-1102
# Got metric value 0.02227589694084131
# Testing layer multi_layer for Расход нафты ККР на установку and Температура сырья перед Е-1103
# Got metric value 0.3874728617474994
# Testing layer multi_layer for Расход нафты ККР на установку and Давление сырья перед Е-1103
# Got metric value 0.09414096087358392
# Testing layer multi_layer for Расход нафты ККР на установку and Температура сырья после Е-1103
# Got metric value 0.0026053667110911283
# Testing layer multi_layer for Расход нафты ККР на установку and Температура ТБ перед Е-1101
# Got metric value 0.0007597833112431562
# Testing layer multi_layer for Расход нафты ККР на установку and Давление ТБ перед Е-1101
# Got metric value 0.12796486738752322
# Testing layer multi_layer for Расход нафты ККР на установку and Температура ТБ после Е-1101
# Got metric value 0.05843837132712004
# Testing layer multi_layer for Расход нафты ККР на установку and Температура бензина перед Е-1102
# Got metric value 0.0022741179686581736
# Testing layer multi_layer for Расход нафты ККР на установку and Температура бензина после Е-1102
# Got metric value -0.003254891046853725
# Testing layer multi_layer for Расход нафты ККР на установку and Давление бензина после Е-1102
# Got metric value 0.03714298426474405
# Testing layer multi_layer for Расход нафты ККР на установку and Температура пара перед Е-1103
# Got metric value 0.12545030926633083
# Testing layer multi_layer for Расход нафты ККР на установку and Давление пара перед Е-1103
# Got metric value 0.009208754202059799
# Testing layer multi_layer for Расход нафты ККР на установку and Давление на входе в R-1101
# Got metric value 0.05172558179642506
# Testing layer multi_layer for Расход нафты ККР на установку and Температура на входе в R-1101
# Got metric value -0.004964153879451816
# Testing layer multi_layer for Расход нафты ККР на установку and Перепад давления реактора R-1101
# Got metric value 0.23580512552167954
# Testing layer multi_layer for Расход нафты ККР на установку and Температура на входе в С-1101
# Got metric value 0.11402134677595954
# Testing layer multi_layer for Расход нафты ККР на установку and Давление верха С-1101
# Got metric value 0.22294169815883214
# Testing layer multi_layer for Расход нафты ККР на установку and Температура 2-ой тарелки С-1101
# Got metric value 0.0006377702572981647
# Testing layer multi_layer for Расход нафты ККР на установку and Расход ЛБ от С-1101
# Got metric value 0.012154061137907513
# Testing layer multi_layer for Расход нафты ККР на установку and Температура ЛБ от С-1101
# Got metric value 0.09539839572230657
# Testing layer multi_layer for Расход нафты ККР на установку and Температура 9-ой тарелки С-1101
# Got metric value 0.01175828240349519
# Testing layer multi_layer for Расход нафты ККР на установку and Температура куба С-1101
# Got metric value 0.05247557078366305
# Testing layer multi_layer for Расход нафты ККР на установку and Уровень куба С-1101
# Got metric value 0.024634583362983853
# Testing layer multi_layer for Расход нафты ККР на установку and Расход ТБ с куба С-1101
# Got metric value 0.3280098487620765
# Testing layer multi_layer for Расход нафты ККР на установку and Расход пара на ребойлеры Е-1105
# Got metric value 0.13988089039836293
# Testing layer multi_layer for Расход нафты ККР на установку and Температура ТБ после ребойлеров Е-1105
# Got metric value 0.03254322183576319
# Testing layer multi_layer for Расход нафты ККР на установку and Давление ЛБ после АВО А-1101
# Got metric value 0.2478089774669222
# Testing layer multi_layer for Расход нафты ККР на установку and Температура ЛБ после АВО А-1101
# Got metric value 0.1030207447848317
# Testing layer multi_layer for Расход нафты ККР на установку and Давление в емкости V-1102
# Got metric value 0.0947611539640294
# Testing layer multi_layer for Расход нафты ККР на установку and Уровень в емкости V-1102
# Got metric value 0.002368288776256944
# Testing layer multi_layer for Расход нафты ККР на установку and Расход насыщенного газа после V-1102
# Got metric value 0.09176210089761139
# Testing layer multi_layer for Расход нафты ККР на установку and Температура окружающей среды
# Got metric value 0.13504925096268094
# Testing layer multi_layer for Расход нафты ККР на установку and Температура ТБ перед Е-1201А
# Got metric value 0.34235856250541763
# Testing layer multi_layer for Расход нафты ККР на установку and Температура ТБ после Е-1201С перед Е-1201D
# Got metric value 0.07219581129377695
# Testing layer multi_layer for Расход нафты ККР на установку and Температура ТБ после Е-1201D
# Got metric value 0.023575853089220944
# Testing layer multi_layer for Расход нафты ККР на установку and Температура ТБ после Е-1201D перед Е-1201C
# Got metric value 0.004292579681393072
# Testing layer multi_layer for Расход нафты ККР на установку and Температура ТБ после Е-1201A
# Got metric value 0.0007597639556636837
# Testing layer multi_layer for Расход нафты ККР на установку and Расход ЛБ на орошение С-1101
# Got metric value 0.17389844293627088
# Testing layer multi_layer for Расход нафты ККР на установку and Температура на входе в R-1201
# Got metric value 0.02264857654509811
# Testing layer multi_layer for Расход нафты ККР на установку and Давление на входе в R-1201
# Got metric value 0.140056674639362
# Testing layer multi_layer for Расход нафты ККР на установку and Перепад давления реактора R-1201
# Got metric value 0.08579042043882146
# Testing layer multi_layer for Расход нафты ККР на установку and Расход квенча реактора R-1201
# Got metric value 0.014804804992712417
# Testing layer multi_layer for Расход нафты ККР на установку and Давление на выходе из R-1201
# Got metric value 0.14866416491013223
# Testing layer multi_layer for Расход нафты ККР на установку and Температура на выходе из R-2101
# Got metric value 0.03603186418829141
# Testing layer multi_layer for Расход нафты ККР на установку and Давление на входе в H-1201
# Got metric value 0.15299568530588614
# Testing layer multi_layer for Расход нафты ККР на установку and Температура на входе в H-1201
# Got metric value 0.03465101618098587
# Testing layer multi_layer for Расход нафты ККР на установку and Давление на выходе из H-1201
# Got metric value 0.19125971556812882
# Testing layer multi_layer for Расход нафты ККР на установку and Температура на выходе из H-1201
# Got metric value -0.2350940328630986
# Testing layer multi_layer for Расход нафты ККР на установку and Уровень в емкости V-1201
# Got metric value 0.11069981892250902
# Testing layer multi_layer for Расход нафты ККР на установку and Давление в емкости V-1201
# Got metric value -0.00015596118575511575
# Testing layer multi_layer for Расход нафты ККР на установку and Температура в емкости V-1201
# Got metric value 0.0623263156452154
# Testing layer multi_layer for Расход нафты ККР на установку and Расход ТБ из емкости V-1201
# Got metric value 0.17304704981839203
# Testing layer multi_layer for Расход нафты ККР на установку and Температура перед А-1201
# Got metric value 0.04108428558548738
# Testing layer multi_layer for Расход нафты ККР на установку and Температура после А-1201
# Got metric value 0.057238516867658906
# Testing layer multi_layer for Расход нафты ККР на установку and Уровень в емкости V-1202
# Got metric value 0.1429034022023833
# Testing layer multi_layer for Расход нафты ККР на установку and Температура в емкости V-1202
# Got metric value 0.05971998053120764
# Testing layer multi_layer for Расход нафты ККР на установку and Давление верха С-1202
# Got metric value 0.08451164334895656
# Testing layer multi_layer for Расход нафты ККР на установку and Температура верха С-1202
# Got metric value 0.05610639938348727
# Testing layer multi_layer for Расход нафты ККР на установку and Температура питания С-1202
# Got metric value 0.05002861224487243
# Testing layer multi_layer for Расход нафты ККР на установку and Температура С-1202
# Got metric value 0.07811842186320017
# Testing layer multi_layer for Расход нафты ККР на установку and Температура глухой тарелки С-1202
# Got metric value 0.08819939523429798
# Testing layer multi_layer for Расход нафты ККР на установку and Давление С-1202
# Got metric value 0.09920911977706859
# Testing layer multi_layer for Расход нафты ККР на установку and Уровень куба С-1202
# Got metric value 0.01533658121937198
# Testing layer multi_layer for Расход нафты ККР на установку and Температура куба С-1202
# Got metric value 0.12043619881048262
# Testing layer multi_layer for Расход нафты ККР на установку and Расход пара на ребойлер Е-1204
# Got metric value 0.10710164172768621
# Testing layer multi_layer for Расход нафты ККР на установку and Температура пара на ребойлер Е-1204
# Got metric value 0.11679343230065342
# Testing layer multi_layer for Расход нафты ККР на установку and Давление пара на ребойлер Е-1204
# Got metric value 0.0009987156982804724
# Testing layer multi_layer for Расход нафты ККР на установку and Температура ТБ после ребойлера Е-1204
# Got metric value 0.1256620609146356
# Testing layer multi_layer for Расход нафты ККР на установку and Возврат ТБ в С-1202 после насосов Р-1204
# Got metric value 0.0019147081601467164
# Testing layer multi_layer for Расход нафты ККР на установку and Расход ТБ после Е-1203
# Got metric value 0.28917594121897083
# Testing layer multi_layer for Расход нафты ККР на установку and Температура ТБ после Е-1203
# Got metric value 0.009309314657219958
# Testing layer multi_layer for Расход нафты ККР на установку and Уровень в емкости V-1205
# Got metric value 0.011152621316445788
# Testing layer multi_layer for Расход нафты ККР на установку and Давление в емкости V-1205
# Got metric value 0.02958097232473844
# Testing layer multi_layer for Расход нафты ККР на установку and Возврат ТБ в V-1205 после насосов Р-1203
# Got metric value 0.04768893825215881
# Testing layer multi_layer for Расход нафты ККР на установку and Расход ТБ из V-1205 после насосов Р-1203
# Got metric value 0.0564638720511883
# Testing layer multi_layer for Расход нафты ККР на установку and Давление ЛБ перед А-1203
# Got metric value -0.008989855205823183
# Testing layer multi_layer for Расход нафты ККР на установку and Температура продукта после А-1203
# Got metric value 0.2695588914600211
# Testing layer multi_layer for Расход нафты ККР на установку and Температура продукта после Е-1205
# Got metric value 0.3956832989400648
# Testing layer multi_layer for Расход нафты ККР на установку and Давление продукта после Е-1205
# Got metric value 0.0003781143464415271
# Testing layer multi_layer for Расход нафты ККР на установку and Давление продукта на выходе с установки
# Got metric value 0.27960566105789453
# Testing layer multi_layer for Расход нафты ККР на установку and Расход продукта на выходе с установки
# Got metric value 0.1398808884050058
# Testing layer multi_layer for Расход нафты ККР на установку and Уровень V-1203
# Got metric value 0.003879804245890295
# Testing layer multi_layer for Расход нафты ККР на установку and Температура V-1203
# Got metric value 0.02729388661339638
# Testing layer multi_layer for Расход нафты ККР на установку and Давление V-1203
# Got metric value 0.008676188362551351
# Testing layer multi_layer for Расход нафты ККР на установку and Температура верха С-1201
# Got metric value 0.05959534279063916
# Testing layer multi_layer for Расход нафты ККР на установку and Давление верха С-1201
# Got metric value 3.41963154952829e-05
# Testing layer multi_layer for Расход нафты ККР на установку and Давление С-1201
# Got metric value 0.0004169047157085437
# Testing layer linear_layer for Расход нафты ККР на установку
# Got metric value 0.09735235660337771
# Testing layer exp_layer for Расход нафты ККР на установку
# Got metric value 0.08067618653613284
# Testing layer log_layer for Расход нафты ККР на установку
# Got metric value 0.11362006323721874
# Testing layer ReLU_layer for Расход нафты ККР на установку
# Got metric value 0.12003140340540952
# Testing layer Tanh_layer for Расход нафты ККР на установку
# Got metric value 0.08213896449517011
# Testing layer abs_layer for Расход нафты ККР на установку
# Got metric value 0.10275809716557593
# Testing layer pow_layer for Расход нафты ККР на установку
# Got metric value 0.02666752393685967
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход бензина ККР на установку
# Got metric value 0.23929050719381872
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход нафты ККР на установку
# Got metric value 0.08605166952096155
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход бензина на рециркуляцию от Е-1205
# Got metric value 0.16359443718633537
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура бензина ККР на установку
# Got metric value 0.05020102164481155
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход сырья после Р-1101
# Got metric value 0.1672006232083607
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Показатель соотношения водород к углероду
# Got metric value 0.1262475490309528
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход водорода на смешение перед Е-1101
# Got metric value 0.18036581267480067
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура сырья перед Е-1101
# Got metric value 0.11344235422162952
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление сырья перед Е-1101
# Got metric value 0.07544044393899829
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура сырья перед Е-1102
# Got metric value 0.1766345111822023
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура сырья перед Е-1103
# Got metric value 0.11344240312831988
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление сырья перед Е-1103
# Got metric value 0.15203216801344666
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура сырья после Е-1103
# Got metric value 0.19295092614410503
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура ТБ перед Е-1101
# Got metric value 0.1869717251166273
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление ТБ перед Е-1101
# Got metric value 0.14783702433013002
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура ТБ после Е-1101
# Got metric value 0.16468022891979517
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура бензина перед Е-1102
# Got metric value 0.18879873573803863
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура бензина после Е-1102
# Got metric value 0.19335044706533244
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление бензина после Е-1102
# Got metric value 0.1570920937978476
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура пара перед Е-1103
# Got metric value 0.07722027247910057
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление пара перед Е-1103
# Got metric value 0.0018704774505754473
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление на входе в R-1101
# Got metric value 0.08744344541738758
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура на входе в R-1101
# Got metric value 0.1941820209142977
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Перепад давления реактора R-1101
# Got metric value 0.13165001698938184
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура на входе в С-1101
# Got metric value 0.19170463883839972
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление верха С-1101
# Got metric value 0.05063217240039475
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура 2-ой тарелки С-1101
# Got metric value 0.17538303395388022
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход ЛБ от С-1101
# Got metric value 0.16929238483794573
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура ЛБ от С-1101
# Got metric value 0.10890200355732815
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура 9-ой тарелки С-1101
# Got metric value 0.003790306691246359
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура куба С-1101
# Got metric value 0.12372850739889285
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Уровень куба С-1101
# Got metric value 0.010928078714125822
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход ТБ с куба С-1101
# Got metric value 0.11402300800166931
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход пара на ребойлеры Е-1105
# Got metric value 0.2329943955772723
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура ТБ после ребойлеров Е-1105
# Got metric value 0.17156313073385443
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление ЛБ после АВО А-1101
# Got metric value 0.047601502830699305
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура ЛБ после АВО А-1101
# Got metric value 0.10173010975258823
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление в емкости V-1102
# Got metric value 0.0004454237568384256
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Уровень в емкости V-1102
# Got metric value 0.018326531932876033
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход насыщенного газа после V-1102
# Got metric value 0.042249491006787876
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура окружающей среды
# Got metric value 0.05567651759527448
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура ТБ перед Е-1201А
# Got metric value 0.09949843335798181
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура ТБ после Е-1201С перед Е-1201D
# Got metric value 0.1905240632835553
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура ТБ после Е-1201D
# Got metric value 0.1980182840107283
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура ТБ после Е-1201D перед Е-1201C
# Got metric value 0.18549043066991122
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура ТБ после Е-1201A
# Got metric value 0.1869743324766424
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход ЛБ на орошение С-1101
# Got metric value 0.2046356666111495
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура на входе в R-1201
# Got metric value 0.19583386948132153
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление на входе в R-1201
# Got metric value 0.1527450873103502
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Перепад давления реактора R-1201
# Got metric value 0.16869897161866454
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход квенча реактора R-1201
# Got metric value 0.1969085425730599
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление на выходе из R-1201
# Got metric value 0.14455953053421333
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура на выходе из R-2101
# Got metric value 0.19667194086420514
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление на входе в H-1201
# Got metric value 0.14874859780067984
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура на входе в H-1201
# Got metric value 0.19732906283318263
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление на выходе из H-1201
# Got metric value 0.12936896531935638
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура на выходе из H-1201
# Got metric value 0.2086930594491796
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Уровень в емкости V-1201
# Got metric value 0.11854007556386137
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление в емкости V-1201
# Got metric value 0.14445097407513574
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура в емкости V-1201
# Got metric value 0.16294135812832278
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход ТБ из емкости V-1201
# Got metric value 0.12365488114397649
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура перед А-1201
# Got metric value 0.11493774653036415
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура после А-1201
# Got metric value 0.04945377098955139
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Уровень в емкости V-1202
# Got metric value 0.049284381010985645
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура в емкости V-1202
# Got metric value 0.04749378280923189
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление верха С-1202
# Got metric value 0.07612443385500767
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура верха С-1202
# Got metric value 0.0038665872717832395
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура питания С-1202
# Got metric value 0.024124098499885283
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура С-1202
# Got metric value 0.04048745561379452
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура глухой тарелки С-1202
# Got metric value 0.004529743306905143
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление С-1202
# Got metric value 0.07974354233399639
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Уровень куба С-1202
# Got metric value 0.17811912539256525
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура куба С-1202
# Got metric value 0.12586058210839823
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход пара на ребойлер Е-1204
# Got metric value 0.03946730792377329
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура пара на ребойлер Е-1204
# Got metric value 0.10982758420998284
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление пара на ребойлер Е-1204
# Got metric value 0.05243024741565949
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура ТБ после ребойлера Е-1204
# Got metric value 0.09401000207195076
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Возврат ТБ в С-1202 после насосов Р-1204
# Got metric value 0.0002019776064785539
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход ТБ после Е-1203
# Got metric value 0.11843227574096571
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура ТБ после Е-1203
# Got metric value 0.16606551352991628
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Уровень в емкости V-1205
# Got metric value 0.09131460115122902
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление в емкости V-1205
# Got metric value 0.047116666216920566
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Возврат ТБ в V-1205 после насосов Р-1203
# Got metric value 0.0376769913985977
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход ТБ из V-1205 после насосов Р-1203
# Got metric value 0.034715662674872805
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление ЛБ перед А-1203
# Got metric value 0.006783016866684033
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура продукта после А-1203
# Got metric value 0.19131163617137992
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура продукта после Е-1205
# Got metric value 0.11496442739675727
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление продукта после Е-1205
# Got metric value 0.19276358543634353
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление продукта на выходе с установки
# Got metric value 0.18565093891189732
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Расход продукта на выходе с установки
# Got metric value 0.23299416823958907
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Уровень V-1203
# Got metric value 0.03284505740406296
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура V-1203
# Got metric value 0.014801484583475522
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление V-1203
# Got metric value 0.09736630641092925
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Температура верха С-1201
# Got metric value 0.0076123974580980525
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление верха С-1201
# Got metric value 0.18253711135224493
# Testing layer multi_layer for Расход бензина на рециркуляцию от Е-1205 and Давление С-1201
# Got metric value 0.11191021705175919
# Testing layer linear_layer for Расход бензина на рециркуляцию от Е-1205
# Got metric value 0.28594023540541524
# Testing layer exp_layer for Расход бензина на рециркуляцию от Е-1205
# Got metric value 0.13104159975319352
# Testing layer log_layer for Расход бензина на рециркуляцию от Е-1205
# Got metric value 0.30647201924004597
# Testing layer ReLU_layer for Расход бензина на рециркуляцию от Е-1205
# Got metric value 0.30369468689376433
# Testing layer Tanh_layer for Расход бензина на рециркуляцию от Е-1205
# Got metric value 0.33221686684941854
# Testing layer abs_layer for Расход бензина на рециркуляцию от Е-1205
# Got metric value 0.2649408520018094
# Testing layer pow_layer for Расход бензина на рециркуляцию от Е-1205
# Got metric value 0.16194092657604275
# Testing layer multi_layer for Температура бензина ККР на установку and Расход бензина ККР на установку
# Got metric value 0.041277830689955275
# Testing layer multi_layer for Температура бензина ККР на установку and Расход нафты ККР на установку
# Got metric value 0.23376049021409329
# Testing layer multi_layer for Температура бензина ККР на установку and Расход бензина на рециркуляцию от Е-1205
# Got metric value 0.05020099724252569
# Testing layer multi_layer for Температура бензина ККР на установку and Температура бензина ККР на установку
# Got metric value 0.11182445162382582
# Testing layer multi_layer for Температура бензина ККР на установку and Расход сырья после Р-1101
# Got metric value 0.024057733838138473
# Testing layer multi_layer for Температура бензина ККР на установку and Показатель соотношения водород к углероду
# Got metric value 0.03423599547727163
# Testing layer multi_layer for Температура бензина ККР на установку and Расход водорода на смешение перед Е-1101
# Got metric value 0.07115699787703289
# Testing layer multi_layer for Температура бензина ККР на установку and Температура сырья перед Е-1101
# Got metric value 0.120334598597854
# Testing layer multi_layer for Температура бензина ККР на установку and Давление сырья перед Е-1101
# Got metric value 0.05114093848722345
# Testing layer multi_layer for Температура бензина ККР на установку and Температура сырья перед Е-1102
# Got metric value 0.09551614527252783
# Testing layer multi_layer for Температура бензина ККР на установку and Температура сырья перед Е-1103
# Got metric value 0.12033459316794715
# Testing layer multi_layer for Температура бензина ККР на установку and Давление сырья перед Е-1103
# Got metric value 0.11194202777730955
# Testing layer multi_layer for Температура бензина ККР на установку and Температура сырья после Е-1103
# Got metric value 0.11338841417580714
# Testing layer multi_layer for Температура бензина ККР на установку and Температура ТБ перед Е-1101
# Got metric value 0.13011563646634494
# Testing layer multi_layer for Температура бензина ККР на установку and Давление ТБ перед Е-1101
# Got metric value 0.040657027104274435
# Testing layer multi_layer for Температура бензина ККР на установку and Температура ТБ после Е-1101
# Got metric value 0.06740233178068444
# Testing layer multi_layer for Температура бензина ККР на установку and Температура бензина перед Е-1102
# Got metric value 0.10252049224780058
# Testing layer multi_layer for Температура бензина ККР на установку and Температура бензина после Е-1102
# Got metric value 0.12698440931064203
# Testing layer multi_layer for Температура бензина ККР на установку and Давление бензина после Е-1102
# Got metric value 0.05123790094942238
# Testing layer multi_layer for Температура бензина ККР на установку and Температура пара перед Е-1103
# Got metric value 0.06585686517457368
# Testing layer multi_layer for Температура бензина ККР на установку and Давление пара перед Е-1103
# Got metric value 0.0036909796932086403
# Testing layer multi_layer for Температура бензина ККР на установку and Давление на входе в R-1101
# Got metric value 0.029479810787900407
# Testing layer multi_layer for Температура бензина ККР на установку and Температура на входе в R-1101
# Got metric value 0.10883190562667322
# Testing layer multi_layer for Температура бензина ККР на установку and Перепад давления реактора R-1101
# Got metric value 0.00214546284145567
# Testing layer multi_layer for Температура бензина ККР на установку and Температура на входе в С-1101
# Got metric value 0.004540180111256009
# Testing layer multi_layer for Температура бензина ККР на установку and Давление верха С-1101
# Got metric value 0.044955767595740936
# Testing layer multi_layer for Температура бензина ККР на установку and Температура 2-ой тарелки С-1101
# Got metric value 0.1873254997136956
# Testing layer multi_layer for Температура бензина ККР на установку and Расход ЛБ от С-1101
# Got metric value 0.056327571171415514
# Testing layer multi_layer for Температура бензина ККР на установку and Температура ЛБ от С-1101
# Got metric value 0.23928765625094917
# Testing layer multi_layer for Температура бензина ККР на установку and Температура 9-ой тарелки С-1101
# Got metric value 0.0029327910406078406
# Testing layer multi_layer for Температура бензина ККР на установку and Температура куба С-1101
# Got metric value 0.0025440346682356063
# Testing layer multi_layer for Температура бензина ККР на установку and Уровень куба С-1101
# Got metric value 0.04741899001960159
# Testing layer multi_layer for Температура бензина ККР на установку and Расход ТБ с куба С-1101
# Got metric value 0.0026260290933939334
# Testing layer multi_layer for Температура бензина ККР на установку and Расход пара на ребойлеры Е-1105
# Got metric value 0.041190319343302084
# Testing layer multi_layer for Температура бензина ККР на установку and Температура ТБ после ребойлеров Е-1105
# Got metric value 0.002027526588020079
# Testing layer multi_layer for Температура бензина ККР на установку and Давление ЛБ после АВО А-1101
# Got metric value 0.051724534832822466
# Testing layer multi_layer for Температура бензина ККР на установку and Температура ЛБ после АВО А-1101
# Got metric value 0.0813573575294223
# Testing layer multi_layer for Температура бензина ККР на установку and Давление в емкости V-1102
# Got metric value 0.042313817677424925
# Testing layer multi_layer for Температура бензина ККР на установку and Уровень в емкости V-1102
# Got metric value 0.006536429495880514
# Testing layer multi_layer for Температура бензина ККР на установку and Расход насыщенного газа после V-1102
# Got metric value 0.03398334948197179
# Testing layer multi_layer for Температура бензина ККР на установку and Температура окружающей среды
# Got metric value 0.025444663943121393
# Testing layer multi_layer for Температура бензина ККР на установку and Температура ТБ перед Е-1201А
# Got metric value 0.07102697918525991
# Testing layer multi_layer for Температура бензина ККР на установку and Температура ТБ после Е-1201С перед Е-1201D
# Got metric value 0.09326030944580121
# Testing layer multi_layer for Температура бензина ККР на установку and Температура ТБ после Е-1201D
# Got metric value 0.241130630836484
# Testing layer multi_layer for Температура бензина ККР на установку and Температура ТБ после Е-1201D перед Е-1201C
# Got metric value 0.20590523613577283
# Testing layer multi_layer for Температура бензина ККР на установку and Температура ТБ после Е-1201A
# Got metric value 0.13011562038111701
# Testing layer multi_layer for Температура бензина ККР на установку and Расход ЛБ на орошение С-1101
# Got metric value 0.018058835840608634
# Testing layer multi_layer for Температура бензина ККР на установку and Температура на входе в R-1201
# Got metric value 0.2397370631519773
# Testing layer multi_layer for Температура бензина ККР на установку and Давление на входе в R-1201
# Got metric value 0.03897047725065772
# Testing layer multi_layer for Температура бензина ККР на установку and Перепад давления реактора R-1201
# Got metric value 0.060487682466413895
# Testing layer multi_layer for Температура бензина ККР на установку and Расход квенча реактора R-1201
# Got metric value 0.23859763528327582
# ...
# Got metric value 0.007469288790151518
# Testing layer multi_layer for Давление верха С-1201 and Давление С-1202
# Got metric value 0.029326803012200364
# Testing layer multi_layer for Давление верха С-1201 and Уровень куба С-1202
# Got metric value 0.187921556274821
# Testing layer multi_layer for Давление верха С-1201 and Температура куба С-1202
# Got metric value 0.0004702604394158927
# Testing layer multi_layer for Давление верха С-1201 and Расход пара на ребойлер Е-1204
# Got metric value 0.055282295371498535
# Testing layer multi_layer for Давление верха С-1201 and Температура пара на ребойлер Е-1204
# Got metric value 0.0427110338051202
# Testing layer multi_layer for Давление верха С-1201 and Давление пара на ребойлер Е-1204
# Got metric value 0.009572916666567788
# Testing layer multi_layer for Давление верха С-1201 and Температура ТБ после ребойлера Е-1204
# Got metric value 9.967442272318383e-05
# Testing layer multi_layer for Давление верха С-1201 and Возврат ТБ в С-1202 после насосов Р-1204
# Got metric value 0.0013497142665699347
# Testing layer multi_layer for Давление верха С-1201 and Расход ТБ после Е-1203
# Got metric value 0.06818853201950648
# Testing layer multi_layer for Давление верха С-1201 and Температура ТБ после Е-1203
# Got metric value 0.08904595319910946
# Testing layer multi_layer for Давление верха С-1201 and Уровень в емкости V-1205
# Got metric value 0.02856680041507864
# Testing layer multi_layer for Давление верха С-1201 and Давление в емкости V-1205
# Got metric value 0.014817971956991749
# Testing layer multi_layer for Давление верха С-1201 and Возврат ТБ в V-1205 после насосов Р-1203
# Got metric value 0.0014420134110704197
# Testing layer multi_layer for Давление верха С-1201 and Расход ТБ из V-1205 после насосов Р-1203
# Got metric value 0.04639259695890019
# Testing layer multi_layer for Давление верха С-1201 and Давление ЛБ перед А-1203
# Got metric value 0.0035271976338129285
# Testing layer multi_layer for Давление верха С-1201 and Температура продукта после А-1203
# Got metric value 0.17528652235833908
# Testing layer multi_layer for Давление верха С-1201 and Температура продукта после Е-1205
# Got metric value 0.13656086814739554
# Testing layer multi_layer for Давление верха С-1201 and Давление продукта после Е-1205
# Got metric value 0.019146420524052576
# Testing layer multi_layer for Давление верха С-1201 and Давление продукта на выходе с установки
# Got metric value 0.05564064817941916
# Testing layer multi_layer for Давление верха С-1201 and Расход продукта на выходе с установки
# Got metric value 0.1966299737272763
# Testing layer multi_layer for Давление верха С-1201 and Уровень V-1203
# Got metric value 0.018389704780599536
# Testing layer multi_layer for Давление верха С-1201 and Температура V-1203
# Got metric value 0.012852579794684016
# Testing layer multi_layer for Давление верха С-1201 and Давление V-1203
# Got metric value 0.00011921351150456783
# Testing layer multi_layer for Давление верха С-1201 and Температура верха С-1201
# Got metric value 0.007006268873402388
# Testing layer multi_layer for Давление верха С-1201 and Давление верха С-1201
# Got metric value 0.0022247119989610153
# Testing layer multi_layer for Давление верха С-1201 and Давление С-1201
# Got metric value -0.0009976636085742285
# Testing layer linear_layer for Давление верха С-1201
# Got metric value 0.002488287183364468
# Testing layer exp_layer for Давление верха С-1201
# Got metric value 0.002362579777949847
# Testing layer log_layer for Давление верха С-1201
# Got metric value 0.0031345373187318115
# Testing layer ReLU_layer for Давление верха С-1201
# Got metric value 0.005455228866238393
# Testing layer Tanh_layer for Давление верха С-1201
# Got metric value 0.12368905676377584
# Testing layer abs_layer for Давление верха С-1201
# Got metric value 0.006628916048613265
# Testing layer pow_layer for Давление верха С-1201
# Got metric value 0.012958747314791297
# Testing layer multi_layer for Давление С-1201 and Расход бензина ККР на установку
# Got metric value 0.14764290396264856
# Testing layer multi_layer for Давление С-1201 and Расход нафты ККР на установку
# Got metric value 0.00041690506699687546
# Testing layer multi_layer for Давление С-1201 and Расход бензина на рециркуляцию от Е-1205
# Got metric value 0.11191020730120993
# Testing layer multi_layer for Давление С-1201 and Температура бензина ККР на установку
# Got metric value 0.014884726649390223
# Testing layer multi_layer for Давление С-1201 and Расход сырья после Р-1101
# Got metric value 0.057808719750966575
# Testing layer multi_layer for Давление С-1201 and Показатель соотношения водород к углероду
# Got metric value 0.049804536756860696
# Testing layer multi_layer for Давление С-1201 and Расход водорода на смешение перед Е-1101
# Got metric value 0.0749038525648843
# Testing layer multi_layer for Давление С-1201 and Температура сырья перед Е-1101
# Got metric value 0.034398761791008314
# Testing layer multi_layer for Давление С-1201 and Давление сырья перед Е-1101
# Got metric value 0.01307403953732078
# Testing layer multi_layer for Давление С-1201 and Температура сырья перед Е-1102
# Got metric value 0.10458819104263173
# Testing layer multi_layer for Давление С-1201 and Температура сырья перед Е-1103
# Got metric value 0.03439875543514004
# Testing layer multi_layer for Давление С-1201 and Давление сырья перед Е-1103
# Got metric value 0.07905831922800077
# Testing layer multi_layer for Давление С-1201 and Температура сырья после Е-1103
# Got metric value 0.13780118003284347
# Testing layer multi_layer for Давление С-1201 and Температура ТБ перед Е-1101
# Got metric value 0.07870594283922605
# Testing layer multi_layer for Давление С-1201 and Давление ТБ перед Е-1101
# Got metric value 0.07842990040128706
# Testing layer multi_layer for Давление С-1201 and Температура ТБ после Е-1101
# Got metric value 0.10591069687303989
# Testing layer multi_layer for Давление С-1201 and Температура бензина перед Е-1102
# Got metric value 0.13887175202576907
# Testing layer multi_layer for Давление С-1201 and Температура бензина после Е-1102
# Got metric value 0.13272550173566633
# Testing layer multi_layer for Давление С-1201 and Давление бензина после Е-1102
# Got metric value 0.07138551972042928
# Testing layer multi_layer for Давление С-1201 and Температура пара перед Е-1103
# Got metric value 0.02643337686197278
# Testing layer multi_layer for Давление С-1201 and Давление пара перед Е-1103
# Got metric value 0.03318604816096016
# Testing layer multi_layer for Давление С-1201 and Давление на входе в R-1101
# Got metric value 0.0048817157600347105
# Testing layer multi_layer for Давление С-1201 and Температура на входе в R-1101
# Got metric value 0.1401640055696698
# Testing layer multi_layer for Давление С-1201 and Перепад давления реактора R-1101
# Got metric value 0.036623641589906275
# Testing layer multi_layer for Давление С-1201 and Температура на входе в С-1101
# Got metric value 0.15615400859088946
# Testing layer multi_layer for Давление С-1201 and Давление верха С-1101
# Got metric value 0.0018058727750384085
# Testing layer multi_layer for Давление С-1201 and Температура 2-ой тарелки С-1101
# Got metric value 0.09297304563382669
# Testing layer multi_layer for Давление С-1201 and Расход ЛБ от С-1101
# Got metric value 0.04991384585491676
# Testing layer multi_layer for Давление С-1201 and Температура ЛБ от С-1101
# Got metric value 0.026910321819168526
# Testing layer multi_layer for Давление С-1201 and Температура 9-ой тарелки С-1101
# Got metric value 1.010854173033593e-06
# Testing layer multi_layer for Давление С-1201 and Температура куба С-1101
# Got metric value 0.005490582064959781
# Testing layer multi_layer for Давление С-1201 and Уровень куба С-1101
# Got metric value 0.0018168080596594471
# Testing layer multi_layer for Давление С-1201 and Расход ТБ с куба С-1101
# Got metric value 0.056491576799803545
# Testing layer multi_layer for Давление С-1201 and Расход пара на ребойлеры Е-1105
# Got metric value 0.13843937289755381
# Testing layer multi_layer for Давление С-1201 and Температура ТБ после ребойлеров Е-1105
# Got metric value 0.011687720105898136
# Testing layer multi_layer for Давление С-1201 and Давление ЛБ после АВО А-1101
# Got metric value 0.0024075308071120904
# Testing layer multi_layer for Давление С-1201 and Температура ЛБ после АВО А-1101
# Got metric value 0.063034056448253
# Testing layer multi_layer for Давление С-1201 and Давление в емкости V-1102
# Got metric value 0.0020476861002318714
# Testing layer multi_layer for Давление С-1201 and Уровень в емкости V-1102
# Got metric value 0.00038442129878579756
# Testing layer multi_layer for Давление С-1201 and Расход насыщенного газа после V-1102
# Got metric value 0.012391014887715879
# Testing layer multi_layer for Давление С-1201 and Температура окружающей среды
# Got metric value 0.019584261680825943
# Testing layer multi_layer for Давление С-1201 and Температура ТБ перед Е-1201А
# Got metric value 9.934699185865092e-06
# Testing layer multi_layer for Давление С-1201 and Температура ТБ после Е-1201С перед Е-1201D
# Got metric value 0.05976068403774493
# Testing layer multi_layer for Давление С-1201 and Температура ТБ после Е-1201D
# Got metric value 0.05366321727152268
# Testing layer multi_layer for Давление С-1201 and Температура ТБ после Е-1201D перед Е-1201C
# Got metric value 0.049074063826178294
# Testing layer multi_layer for Давление С-1201 and Температура ТБ после Е-1201A
# Got metric value 0.0787059479073774
# Testing layer multi_layer for Давление С-1201 and Расход ЛБ на орошение С-1101
# Got metric value 0.16235965449981105
# Testing layer multi_layer for Давление С-1201 and Температура на входе в R-1201
# Got metric value 0.05290111108855344
# Testing layer multi_layer for Давление С-1201 and Давление на входе в R-1201
# Got metric value 0.07485305676317655
# Testing layer multi_layer for Давление С-1201 and Перепад давления реактора R-1201
# Got metric value 0.08140539120777557
# Testing layer multi_layer for Давление С-1201 and Расход квенча реактора R-1201
# Got metric value 0.050747628283084545
# Testing layer multi_layer for Давление С-1201 and Давление на выходе из R-1201
# Got metric value 0.07210544968851329
# Testing layer multi_layer for Давление С-1201 and Температура на выходе из R-2101
# Got metric value 0.04843519847462563
# Testing layer multi_layer for Давление С-1201 and Давление на входе в H-1201
# Got metric value 0.07284462228647104
# Testing layer multi_layer for Давление С-1201 and Температура на входе в H-1201
# Got metric value 0.04932706318631286
# Testing layer multi_layer for Давление С-1201 and Давление на выходе из H-1201
# Got metric value 0.06548090911802873
# Testing layer multi_layer for Давление С-1201 and Температура на выходе из H-1201
# Got metric value 0.06361336749860291
# Testing layer multi_layer for Давление С-1201 and Уровень в емкости V-1201
# Got metric value 0.01861880933478266
# Testing layer multi_layer for Давление С-1201 and Давление в емкости V-1201
# Got metric value 0.03151227749268859
# Testing layer multi_layer for Давление С-1201 and Температура в емкости V-1201
# Got metric value 0.10344873535912846
# Testing layer multi_layer for Давление С-1201 and Расход ТБ из емкости V-1201
# Got metric value 0.055640476457625265
# Testing layer multi_layer for Давление С-1201 and Температура перед А-1201
# Got metric value 0.05144315007765854
# Testing layer multi_layer for Давление С-1201 and Температура после А-1201
# Got metric value 0.03787102185233815
# Testing layer multi_layer for Давление С-1201 and Уровень в емкости V-1202
# Got metric value 0.00028961264687488164
# Testing layer multi_layer for Давление С-1201 and Температура в емкости V-1202
# Got metric value 0.03466614017366565
# Testing layer multi_layer for Давление С-1201 and Давление верха С-1202
# Got metric value 0.0006052198529102881
# Testing layer multi_layer for Давление С-1201 and Температура верха С-1202
# Got metric value 0.004500985466160845
# Testing layer multi_layer for Давление С-1201 and Температура питания С-1202
# Got metric value 0.00842201675298071
# Testing layer multi_layer for Давление С-1201 and Температура С-1202
# Got metric value 0.003125627307612344
# Testing layer multi_layer for Давление С-1201 and Температура глухой тарелки С-1202
# Got metric value 0.0009975158025983255
# Testing layer multi_layer for Давление С-1201 and Давление С-1202
# Got metric value 0.0008862502462295696
# Testing layer multi_layer for Давление С-1201 and Уровень куба С-1202
# Got metric value 0.1299826328157565
# Testing layer multi_layer for Давление С-1201 and Температура куба С-1202
# Got metric value 0.0015946987648288724
# Testing layer multi_layer for Давление С-1201 and Расход пара на ребойлер Е-1204
# Got metric value 0.046638528067752594
# Testing layer multi_layer for Давление С-1201 and Температура пара на ребойлер Е-1204
# Got metric value 0.0029484471419494174
# Testing layer multi_layer for Давление С-1201 and Давление пара на ребойлер Е-1204
# Got metric value 0.00887168481136491
# Testing layer multi_layer for Давление С-1201 and Температура ТБ после ребойлера Е-1204
# Got metric value 0.0007816461050392798
# Testing layer multi_layer for Давление С-1201 and Возврат ТБ в С-1202 после насосов Р-1204
# Got metric value 0.00028399474441664907
# Testing layer multi_layer for Давление С-1201 and Расход ТБ после Е-1203
# Got metric value 0.059013829165993736
# Testing layer multi_layer for Давление С-1201 and Температура ТБ после Е-1203
# Got metric value 0.08518588426615659
# Testing layer multi_layer for Давление С-1201 and Уровень в емкости V-1205
# Got metric value 0.004364425922004922
# Testing layer multi_layer for Давление С-1201 and Давление в емкости V-1205
# Got metric value 3.3399541189305104e-05
# Testing layer multi_layer for Давление С-1201 and Возврат ТБ в V-1205 после насосов Р-1203
# Got metric value 0.0006178318225966706
# Testing layer multi_layer for Давление С-1201 and Расход ТБ из V-1205 после насосов Р-1203
# Got metric value 0.038006174492537625
# Testing layer multi_layer for Давление С-1201 and Давление ЛБ перед А-1203
# Got metric value 0.002633721439394665
# Testing layer multi_layer for Давление С-1201 and Температура продукта после А-1203
# Got metric value 0.04687898911972954
# Testing layer multi_layer for Давление С-1201 and Температура продукта после Е-1205
# Got metric value 0.06245482868087704
# Testing layer multi_layer for Давление С-1201 and Давление продукта после Е-1205
# Got metric value 0.03529935915956828
# Testing layer multi_layer for Давление С-1201 and Давление продукта на выходе с установки
# Got metric value 0.04982211569663175
# Testing layer multi_layer for Давление С-1201 and Расход продукта на выходе с установки
# Got metric value 0.13843937706042286
# Testing layer multi_layer for Давление С-1201 and Уровень V-1203
# Got metric value 0.05277051255277765
# Testing layer multi_layer for Давление С-1201 and Температура V-1203
# Got metric value 0.0275902520658472
# Testing layer multi_layer for Давление С-1201 and Давление V-1203
# Got metric value 0.00032944353518848946
# Testing layer multi_layer for Давление С-1201 and Температура верха С-1201
# Got metric value 0.02228017057496401
# Testing layer multi_layer for Давление С-1201 and Давление верха С-1201
# Got metric value 0.00016627180840422806
# Testing layer multi_layer for Давление С-1201 and Давление С-1201
# Got metric value 3.3943910477951533e-06
# Testing layer linear_layer for Давление С-1201
# Got metric value 1.459480027277138e-06
# Testing layer exp_layer for Давление С-1201
# Got metric value 1.491899652705797e-06
# Testing layer log_layer for Давление С-1201
# Got metric value 0.002156044935194723
# Testing layer ReLU_layer for Давление С-1201
# Got metric value 1.5317747070753285e-12
# Testing layer Tanh_layer for Давление С-1201
# Got metric value 0.007462396314823594
# Testing layer abs_layer for Давление С-1201
# Got metric value -0.018294518554121453
# Testing layer pow_layer for Давление С-1201
# Got metric value 0.0175227341596893
# Done layer 1
#
# New model:
#
# Y = 1*(-0.23) + 1*(1.09) * tanh((1.47) * (Давление в емкости V-1201) + (0.44)
#
# New best score 0.7164984836855008
#
# New score on Test -1.1778233431500644
#
# -------------------------------------------------------------------------------------------------------------------------------

# %%
class NonlinearSoftSensor(Essentials.SoftSensor):
    def __init__(self, name, x_train, y_train, x_test, y_test, labels, lr):
        super().__init__(name)
        self.lr = lr
        self.x_scaler = StandardScaler() 
        self.y_scaler = StandardScaler()
        self.fit_scaler(x_train, y_train)

        self.r2_score = Essentials.R2Metric()

        self.labels_x = [RegressionLayer([start_layer()], label, data_from_dict=True) for label in labels]
        self.c_label = RegressionLayer([const_layer()], 'const', data_from_dict=True)
        self.labels_x.append(c_label)

        X_train_norm = self.prepocessing(x_train)
        X_test_norm = self.prepocessing(x_test)
        Y_train_norm = self.prepocessing(y_train)
        Y_test_norm = self.prepocessing(y_test)
        
        vectors_x_train = [torch.tensor(col, dtype=torch.float32) for col in X_train_norm.T]
        vectors_x_train.append(torch.ones(vectors_x_train[0].shape))
        vectors_x_test = [torch.tensor(col, dtype=torch.float32) for col in X_test_norm.T]
        vectors_x_test.append(torch.ones(vectors_x_test[0].shape))

        self.x_train_model = {key: value for key, value in zip(self.labels_x, vectors_x_train)}
        self.y_train_model = torch.tensor(Y_train_norm, dtype=torch.float32)
        
        self.x_test_model = {key: value for key, value in zip(self.labels_x, vectors_x_test)}
        self.y_test_model = torch.tensor(Y_test_norm, dtype=torch.float32)
        
        model = RegressionModel(self.r2_score, self.lr)
        model.add_layer(RegressionLayer([const_layer()], self.c_label))
        
        self.criterion = torch.nn.MSELoss()
        self.train_model(model, self.x_train_model, self.y_train_model)
        model.disable_training()
        self.set_model(model)
        

    def preprocessing(self, x):
        try:
            return torch.tensor(self.x_scaler.transform(x), dtype=torch.float32)
        except:
            try:
               return torch.tensor(self.y_scaler.transform(x), dtype=torch.float32)
            except BaseException as err:
                print("Ошибка скейлера")
                raise err
        
            
    def fit_scaler(self, x_train, y_train):
        self.x_scaler.fit(x_train)
        self.y_scaler.fit(y_train)

    def train_model(model, X, Y, lr=0.005, epoch_num=1000, verbose=False):    
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
        for i in range(epoch_num):
            optimizer.zero_grad()
            Y_pred = model(X)
            loss = criterion(Y_pred, Y.squeeze())
            loss.backward()
            optimizer.step()
            if verbose:
                print(loss.item()) 

    
    def postprocessing(self, x):
        try:
            x_post = x.detach().numpy()
            return self.x_scaler.inverse_transform(x_post)
        except:
            try:
                x_post = x.detach().numpy()
                return self.y_scaler.inverse_transform(x_post)
            except BaseException as err:
                print("Ошибка скейлера")
                raise err

    def evaluate_model(self, x):
        model = self.get_model()
        return model(x)


    def train(self, possible_layers, comb_layers, max_layers, max_diff=0.01, verbose=False, verbose2=True, ):
        
        start_layers = self.labels_x[:-1]
        
        x1 = self.x_train_model
        y1 = self.y_train_model
        
        x2 = self.x_test_model
        y2 = self.y_test_model        
        
        Model = self.get_model()    
        model_layers = Model.get_layers()       
                
        # iterate over max_layers
        for i in range(max_layers):
            best_layers = None
            best_step_score = Model.get_metric(x1, y1)
        
            for prev_layer in (start_layers + model_layers):
                if isinstance(prev_layer.torch_layers[0], const_layer):
                    continue
               
                for layer in (comb_layers + possible_layers):
        
                    if layer in comb_layers:
                        for second_layer in (start_layers + model_layers):
                            if isinstance(second_layer.torch_layers[0], const_layer):
                                continue
                            step_layers = Model.get_layers()
                            step_layers.append(RegressionLayer([layer(second_layer)], prev_layer))
                            if verbose2:
                                print(f"Testing layer {layer.__name__} for {prev_layer.__str__()} and {second_layer.__str__()}")
                                
                            step_model = RegressionModel(self.r2_score, self.lr, step_layers)
                            self.train_model(step_model, x1, y1, epoch_num=1000, verbose=verbose)
                            step_score = step_model.get_metric(x1, y1)
                            if verbose2:
                                print(f'Got metric value {step_score}')
                
                            if step_score > best_step_score:
                                best_step_score = step_score
                                best_layers = step_layers
                                
                    else:
                        step_layers = Model.get_layers()
                        step_layers.append(RegressionLayer([layer()], prev_layer))
                        if verbose2:
                            print(f"Testing layer {layer.__name__} for {prev_layer.__str__()}")          
                           
                        step_model = RegressionModel(self.r2_score, self.lr, step_layers)
                        self.train_model(step_model, x1, y1, epoch_num=1000, verbose=verbose)
                        step_score = step_model.get_metric(x1, y1)
                        if verbose2:
                            print(f'Got metric value {step_score}')
            
                        if step_score > best_step_score:
                            best_step_score = step_score
                            best_layers = step_layers
                    
        
            print(f"Done layer {i+1} \n")
        
            if best_layers is None:
                print('No better layers')
                break
        
            if best_step_score < max_diff*Model.get_metric(x1, y1):
                print("Weak increase")
                break
        
            Model = RegressionModel(self.r2_score, self.lr, best_layers)
            model_layers = Model.get_layers()
            print("New model: \n")
            print(Model, '\n')
            print(f'New best score {Model.get_metric(x1, y1)} \n')
            print(f'New score on Test {Model.get_metric(x2, y2)} \n')
            print('-------------------------------------------------------------------------------------------------------------------------------')
            Model.disable_training()

        self.set_model(Model)


    def __str__(self):
        return self.get_model().__str__()

# %%
Test_sensor_1 = TestSoftSensor(X_train_1, Y_train_1)

# %%
print(Test_sensor_1)

# %%
metric = Essentials.R2Metric()

# %%
test_visual = Essentials.Visualizer(X_train_1, Y_train_1, timestamp_train_1, [metric], 'Test SoftSensor R2 metric')

# %%
test_visual.visualize([Test_sensor_1])

# %%
test_visual_2 = Essentials.Visualizer(X_test_1, Y_test_1, timestamp_test_1, [metric], 'Test SoftSensor R2 metric')

# %%
test_visual_2.visualize([Test_sensor_1])

# %%
print('Final model: \n')
print(Model, '\n')
print(f'Train score {Model.get_metric(x1, y1)} \n')
print(f'Test score {Model.get_metric(x2, y2)} \n')

# %%
linear_model = LinearRegression()
linear_model.fit(X_train_norm, Y_train_norm)

# %%
predictions = linear_model.predict(X_test_norm)
r2_score(Y_test_norm, predictions)

# %%
predictions = linear_model.predict(X_train_norm)
r2_score(Y_train_norm, predictions)
