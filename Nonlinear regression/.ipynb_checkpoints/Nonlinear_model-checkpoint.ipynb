# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import torch
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.plot(kind='density', subplots=True, layout=(14,6), sharex=False, figsize= (30,60))
plt.show()

# %%
labels = list(df.columns)[:-1]

# %%
df_np = df.to_numpy()
x_raw = df_np[:, :-1]
y_raw = df_np[:, -1].reshape(-1, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_raw, y_raw, test_size=0.25, shuffle=True)

# %%
x_scaler = StandardScaler()
y_scaler = StandardScaler()

x_scaler.fit(X_train)
y_scaler.fit(Y_train)
# Out:
# StandardScaler()

# %%
X_train_norm = x_scaler.transform(X_train)
Y_train_norm = y_scaler.transform(Y_train)

X_test_norm = x_scaler.transform(X_test)
Y_test_norm = y_scaler.transform(Y_test)

# %%
X_train_norm.shape
# Out:
# (1199, 11)

# %%
class RegressionModel(torch.nn.Module):
    def __init__(self, metric, lr, layers=[]):
        super().__init__()
        self.layers = torch.nn.ModuleList(layers)
        self.metric = metric
        self.lr = lr
        
    def add_layer(self, layer):
        self.layers.append(layer)

    def forward(self, x_dict):
        res = torch.zeros(list(x_dict.values())[0].shape)
        for layer in self.layers:
            res = res + layer(x_dict)
        return res

    def disable_training(self):
        for layer in self.layers[1:]:
            layer.disable_training(self.lr)

    def get_metric(self, x_dict, y_true):
        y_pred = self.forward(x_dict)
        return self.metric(y_true, y_pred.detach())

    def get_layers(self):
        return list(self.layers)

    def __str__(self):
        string = ''
        for layer in self.layers:
            string = string + ' + ' + str(layer.lr_coeff) + '*' + layer.__str__()
        return 'Y = ' + string[3:]

# %%
class RegressionLayer(torch.nn.Module):
    def __init__(self, torch_layers: list, input_layer, data_from_dict = False):
        super().__init__()
        self.torch_layers = torch.nn.Sequential(*torch_layers)
        self.input_layer = input_layer
        self.data_from_dict = data_from_dict
        self.lr_coeff = 1

    def forward(self, x_dict):
        if self.data_from_dict:
            x_data = x_dict[self]                        
        else:
            x_data = self.input_layer(x_dict)
        if isinstance(self.torch_layers[0], multi_layer):
            return self.torch_layers([x_data, x_dict])
        return self.lr_coeff * self.torch_layers(x_data)

    def __str__(self):
        input_string = self.input_layer.__str__()
        for torch_layer in self.torch_layers:
            torch_layer.set_input(input_string)
            res_string = torch_layer.__str__()
            input_string = res_string
        
        return res_string

    def disable_training(self, lr):
        self.lr_coeff = lr
        for torch_layer in self.torch_layers:
            for param in torch_layer.parameters():
                param.requires_grad = False

# %%
class CombinationLayer(RegressionLayer):
    def __init__(self, torch_layers, input_layer, other_layers, data_from_dict = False):
        super().__init__(torch_layers, input_layer, data_from_dict = False)
        self.torch_layers = torch_layers
        self.other_layers = other_layers

    def forward(self, x_dict):
        x_data = []
        if self.data_from_dict:
            x_data.append(x_dict[self])                        
        else:
            x_data.append(self.input_layer(x_dict))
        for comb_layer in self.other_layers:
            x_data.append(comb_layer(x_dict))
            # if comb_layer.data_from_dict:
            #     x_data.append(x_dict[comb_layer])                        
            # else:
            #     x_data.append(comb_layer(x_dict))
        return self.torch_layers(x_data)

# %%
class TorchLayer(torch.nn.Module):
    
    size = 0
    ndigs = 2

    def __init__(self):
        super().__init__()
        self.weights = torch.nn.Parameter(torch.empty(self.size))
        torch.nn.init.normal_(self.weights) 
        self.input_layer = None

    def forward(self, x_data):
        pass

    def set_input(self, input_layer):
        self.input_layer = input_layer

# %%
def round2(weight, ndigits):
    return round(weight.detach().item(), ndigits)

# %%
class linear_layer(TorchLayer):
       
    size = 1

    def forward(self, x):
        return self.weights[0]*x

    def __str__(self):
        return f"({round2(self.weights[0], self.ndigs)}) * ({self.input_layer})"  


class exp_layer(TorchLayer):

    size = 2

    def forward(self, x):
        return self.weights[1] * (torch.exp(self.weights[0]*x) - 1)

    def __str__(self):
        return f"({round2(self.weights[1], self.ndigs)}) * (exp({round2(self.weights[0], self.ndigs)} * ({self.input_layer})) - 1)"


class log_layer(TorchLayer):
        
    size = 3

    def forward(self, x):
        return self.weights[2] * torch.log(torch.abs(self.weights[1]*x + self.weights[0]) + 1)

    def __str__(self):
        return f"({round2(self.weights[2], self.ndigs)}) * ln(1 + abs({round2(self.weights[0], self.ndigs)} + ({round2(self.weights[1], self.ndigs)}) * ({self.input_layer})))"    


class start_layer(TorchLayer):
    
    size = 0

    def forward(self, x):
        return x

    def __str__(self):
        return f"{self.input_layer}"  


class const_layer(TorchLayer):
    
    size = 1

    def forward(self, x):
        return self.weights[0] * torch.ones(x.shape)

    def __str__(self):
        return f"({round2(self.weights[0], self.ndigs)})"  


class ReLU_layer(TorchLayer):
        
    size = 3

    def __init__(self):
        super().__init__()
        self.relu = torch.nn.ReLU()

    def forward(self, x):
        tmp = self.weights[1] + x*self.weights[0]
        return self.weights[2] * self.relu(tmp)

    def __str__(self):
        return f"({round2(self.weights[2], self.ndigs)}) * max(0, ({round2(self.weights[0], self.ndigs)}) * ({self.input_layer}) + ({round2(self.weights[1], self.ndigs)})"    


class Tanh_layer(TorchLayer):
        
    size = 3

    def __init__(self):
        super().__init__()
        self.tanh = torch.nn.Tanh()

    def forward(self, x):
        tmp = self.weights[1] + x*self.weights[0]
        return self.weights[2] * self.tanh(tmp)

    def __str__(self):
        return f"({round2(self.weights[2], self.ndigs)}) * tanh(({round2(self.weights[0], self.ndigs)}) * ({self.input_layer}) + ({round2(self.weights[1], self.ndigs)})"  


class multi_layer(TorchLayer):
        
    size = 1

    def __init__(self, second_layer):
        super().__init__()
        self.second_x = second_layer

    def forward(self, x):
        return self.weights[0] * x[0] * self.second_x(x[1])

    def __str__(self):
        return f"({round2(self.weights[0], self.ndigs)}) * ({self.input_layer}) * ({self.second_x.__str__()})"  


class abs_layer(TorchLayer):
        
    size = 1

    def forward(self, x):
        return self.weights[0] * torch.abs(x)

    def __str__(self):
        return f"({round2(self.weights[0], self.ndigs)}) * abs({self.input_layer})"  


class pow_layer(TorchLayer):
        
    size = 2

    def forward(self, x):
        return self.weights[1] * torch.pow(torch.abs(x), self.weights[0])

    def __str__(self):
        return f"({round2(self.weights[1], self.ndigs)}) * (abs({self.input_layer}) ** ({round2(self.weights[0], self.ndigs)}))"

# %%
def train(model, X, Y, epoch_num=1000, verbose=True):    
    optimizer = torch.optim.Adam(model.parameters(), lr=0.005)

    for i in range(epoch_num):
        optimizer.zero_grad()
        Y_pred = model(X)
        loss = criterion(Y_pred, Y.squeeze())
        loss.backward()
        optimizer.step()
        if verbose:
            print(loss.item())

# %%
labels_x = [RegressionLayer([start_layer()], label, data_from_dict=True) for label in labels]
c_label = RegressionLayer([const_layer()], 'const', data_from_dict=True)
labels_x.append(c_label)

vectors_x_train = [torch.tensor(col, dtype=torch.float32) for col in X_train_norm.T]
vectors_x_train.append(torch.ones(vectors_x_train[0].shape))
vectors_x_test = [torch.tensor(col, dtype=torch.float32) for col in X_test_norm.T]
vectors_x_test.append(torch.ones(vectors_x_test[0].shape))

# %%
x_train_model = {key: value for key, value in zip(labels_x, vectors_x_train)}
y_train_model = torch.tensor(Y_train_norm, dtype=torch.float32)

x_test_model = {key: value for key, value in zip(labels_x, vectors_x_test)}
y_test_model = torch.tensor(Y_test_norm, dtype=torch.float32)

# %%
possible_layers = [linear_layer, exp_layer, log_layer, ReLU_layer, Tanh_layer, abs_layer, pow_layer]
start_layers = labels_x[:-1]
comb_layers = [multi_layer]

verbose = False
verbose2 = True

x1 = x_train_model
y1 = y_train_model

x2 = x_test_model
y2 = y_test_model

lr = 0.5
max_layers = 10

Model = RegressionModel(r2_score, lr)
Model.add_layer(RegressionLayer([const_layer()], c_label))
criterion = torch.nn.MSELoss()
train(Model, x1, y1, epoch_num=1000, verbose=verbose)
Model.disable_training()


model_layers = Model.get_layers()



# iterate over max_layers
for i in range(max_layers):
    best_layers = None
    best_step_score = Model.get_metric(x1, y1)

    for prev_layer in (start_layers + model_layers):
        if isinstance(prev_layer.torch_layers[0], const_layer):
            continue
       
        for layer in (comb_layers + possible_layers):

            if layer in comb_layers:
                for second_layer in (start_layers + model_layers):
                    if isinstance(second_layer.torch_layers[0], const_layer):
                        continue
                    step_layers = Model.get_layers()
                    step_layers.append(RegressionLayer([layer(second_layer)], prev_layer))
                    if verbose2:
                        print(f"Testing layer {layer.__name__} for {prev_layer.__str__()} and {second_layer.__str__()}")
                        
                    step_model = RegressionModel(r2_score, lr, step_layers)
                    train(step_model, x1, y1, epoch_num=1000, verbose=verbose)
                    step_score = step_model.get_metric(x1, y1)
                    if verbose2:
                        print(f'Got metric value {step_score}')
        
                    if step_score > best_step_score:
                        best_step_score = step_score
                        best_layers = step_layers
                        
            else:
                step_layers = Model.get_layers()
                step_layers.append(RegressionLayer([layer()], prev_layer))
                if verbose2:
                    print(f"Testing layer {layer.__name__} for {prev_layer.__str__()}")          
                   
                step_model = RegressionModel(r2_score, lr, step_layers)
                train(step_model, x1, y1, epoch_num=1000, verbose=verbose)
                step_score = step_model.get_metric(x1, y1)
                if verbose2:
                    print(f'Got metric value {step_score}')
    
                if step_score > best_step_score:
                    best_step_score = step_score
                    best_layers = step_layers
            

    print(f"Done layer {i+1} \n")

    if best_layers is None:
        print('No better layers')
        break

    if best_step_score < 1.01*Model.get_metric(x1, y1):
        print("Weak increase")
        break

    Model = RegressionModel(r2_score, lr, best_layers)
    model_layers = Model.get_layers()
    print("New model: \n")
    print(Model, '\n')
    print(f'New best score {Model.get_metric(x1, y1)} \n')
    print(f'New score on Test {Model.get_metric(x2, y2)} \n')
    print('-------------------------------------------------------------------------------------------------------------------------------')
    Model.disable_training()
# Out:
# Testing layer multi_layer for fixed acidity and fixed acidity
# Got metric value 0.012026537025712325
# Testing layer multi_layer for fixed acidity and volatile acidity
# Got metric value 0.0010770057113766995
# Testing layer multi_layer for fixed acidity and citric acid
# Got metric value 0.009920665207327595
# Testing layer multi_layer for fixed acidity and residual sugar
# Got metric value 0.0013782438603610059
# Testing layer multi_layer for fixed acidity and chlorides
# Got metric value 1.097043590614355e-05
# Testing layer multi_layer for fixed acidity and free sulfur dioxide
# Got metric value 0.00804854836420954
# Testing layer multi_layer for fixed acidity and total sulfur dioxide
# Got metric value 0.015087306129738298
# Testing layer multi_layer for fixed acidity and density
# Got metric value 0.013184932465572063
# Testing layer multi_layer for fixed acidity and pH
# Got metric value 0.0075848170901671175
# Testing layer multi_layer for fixed acidity and sulphates
# Got metric value 0.0034228892034157132
# Testing layer multi_layer for fixed acidity and alcohol
# Got metric value 0.001595358323252416
# Testing layer multi_layer for volatile acidity and fixed acidity
# Got metric value 0.00107700357997631
# Testing layer multi_layer for volatile acidity and volatile acidity
# Got metric value 0.014729804682173775
# Testing layer multi_layer for volatile acidity and citric acid
# Got metric value 0.000125050044220254
# Testing layer multi_layer for volatile acidity and residual sugar
# Got metric value 0.0004181403885532564
# Testing layer multi_layer for volatile acidity and chlorides
# Got metric value 0.0024349173370905586
# Testing layer multi_layer for volatile acidity and free sulfur dioxide
# Got metric value 0.011964991036313988
# Testing layer multi_layer for volatile acidity and total sulfur dioxide
# Got metric value 0.015878647906639953
# Testing layer multi_layer for volatile acidity and density
# Got metric value 0.008324257746601837
# Testing layer multi_layer for volatile acidity and pH
# Got metric value 0.0013797304981559844
# Testing layer multi_layer for volatile acidity and sulphates
# Got metric value 3.994113848948544e-05
# Testing layer multi_layer for volatile acidity and alcohol
# Got metric value 0.02445868035652088
# Testing layer multi_layer for citric acid and fixed acidity
# Got metric value 0.016054742749043616
# Testing layer multi_layer for citric acid and volatile acidity
# Got metric value 0.0001220247730243651
# Testing layer multi_layer for citric acid and citric acid
# Got metric value 0.007361925526893631
# Testing layer multi_layer for citric acid and residual sugar
# Got metric value 0.005400821370852071
# Testing layer multi_layer for citric acid and chlorides
# Got metric value 0.005434200466621575
# Testing layer multi_layer for citric acid and free sulfur dioxide
# Got metric value 0.01838334512077533
# Testing layer multi_layer for citric acid and total sulfur dioxide
# Got metric value 0.031742471368042535
# Testing layer multi_layer for citric acid and density
# Got metric value 0.0025778468323838233
# Testing layer multi_layer for citric acid and pH
# Got metric value 0.00523069191502501
# Testing layer multi_layer for citric acid and sulphates
# Got metric value 0.0003770961820046548
# Testing layer multi_layer for citric acid and alcohol
# Got metric value 0.012444132626430626
# Testing layer multi_layer for residual sugar and fixed acidity
# Got metric value 0.0013782432327474892
# Testing layer multi_layer for residual sugar and volatile acidity
# Got metric value 0.00038372074842851767
# Testing layer multi_layer for residual sugar and citric acid
# Got metric value 0.005400822396938065
# Testing layer multi_layer for residual sugar and residual sugar
# Got metric value 4.440073651412746e-06
# Testing layer multi_layer for residual sugar and chlorides
# Got metric value 0.0005403527091076832
# Testing layer multi_layer for residual sugar and free sulfur dioxide
# Got metric value 0.0012938918518843323
# Testing layer multi_layer for residual sugar and total sulfur dioxide
# Got metric value 0.000176462354787299
# Testing layer multi_layer for residual sugar and density
# Got metric value -0.0014784174559350216
# Testing layer multi_layer for residual sugar and pH
# Got metric value 0.002420072768419379
# Testing layer multi_layer for residual sugar and sulphates
# Got metric value 0.00017943181187718427
# Testing layer multi_layer for residual sugar and alcohol
# Got metric value 0.000791752389593281
# Testing layer multi_layer for chlorides and fixed acidity
# Got metric value -0.009329467659607849
# Testing layer multi_layer for chlorides and volatile acidity
# Got metric value 0.0024349224232457223
# Testing layer multi_layer for chlorides and citric acid
# Got metric value 0.005437018601692767
# Testing layer multi_layer for chlorides and residual sugar
# Got metric value 0.0005403555661255277
# Testing layer multi_layer for chlorides and chlorides
# Got metric value 0.005027621770156032
# Testing layer multi_layer for chlorides and free sulfur dioxide
# Got metric value 0.0014140781025400173
# Testing layer multi_layer for chlorides and total sulfur dioxide
# Got metric value 0.002121370276249035
# Testing layer multi_layer for chlorides and density
# Got metric value 0.00889528901242198
# Testing layer multi_layer for chlorides and pH
# Got metric value 0.005049106838420636
# Testing layer multi_layer for chlorides and sulphates
# Got metric value 0.008783161020056829
# Testing layer multi_layer for chlorides and alcohol
# Got metric value 0.0013215657371413725
# Testing layer multi_layer for free sulfur dioxide and fixed acidity
# Got metric value 0.00804854142628375
# Testing layer multi_layer for free sulfur dioxide and volatile acidity
# Got metric value 0.011964990211406068
# Testing layer multi_layer for free sulfur dioxide and citric acid
# Got metric value 0.01838356441203448
# Testing layer multi_layer for free sulfur dioxide and residual sugar
# Got metric value 0.0012774723448358838
# Testing layer multi_layer for free sulfur dioxide and chlorides
# Got metric value 0.001414075846859708
# Testing layer multi_layer for free sulfur dioxide and free sulfur dioxide
# Got metric value 6.739609847727923e-05
# Testing layer multi_layer for free sulfur dioxide and total sulfur dioxide
# Got metric value 0.00485186596838616
# Testing layer multi_layer for free sulfur dioxide and density
# Got metric value 0.006596957465751285
# Testing layer multi_layer for free sulfur dioxide and pH
# Got metric value 0.012202191528755346
# Testing layer multi_layer for free sulfur dioxide and sulphates
# Got metric value 0.004987619579356561
# Testing layer multi_layer for free sulfur dioxide and alcohol
# Got metric value 0.0018189015487982685
# Testing layer multi_layer for total sulfur dioxide and fixed acidity
# Got metric value 0.015087304476530283
# Testing layer multi_layer for total sulfur dioxide and volatile acidity
# Got metric value 0.01587865417840606
# Testing layer multi_layer for total sulfur dioxide and citric acid
# Got metric value 0.03174247254922957
# Testing layer multi_layer for total sulfur dioxide and residual sugar
# Got metric value 0.0001764620689435059
# Testing layer multi_layer for total sulfur dioxide and chlorides
# Got metric value 0.002121369990405242
# Testing layer multi_layer for total sulfur dioxide and free sulfur dioxide
# Got metric value 0.004850650976950255
# Testing layer multi_layer for total sulfur dioxide and total sulfur dioxide
# Got metric value 0.008423069258382765
# Testing layer multi_layer for total sulfur dioxide and density
# Got metric value 0.007039513792107321
# Testing layer multi_layer for total sulfur dioxide and pH
# Got metric value 0.019232637853449086
# Testing layer multi_layer for total sulfur dioxide and sulphates
# Got metric value 0.009711832396993358
# Testing layer multi_layer for total sulfur dioxide and alcohol
# Got metric value 0.001973014787038485
# Testing layer multi_layer for density and fixed acidity
# Got metric value 0.013184938603664431
# Testing layer multi_layer for density and volatile acidity
# Got metric value 0.008324259992669836
# Testing layer multi_layer for density and citric acid
# Got metric value 0.0025778494422619147
# Testing layer multi_layer for density and residual sugar
# Got metric value 6.8313060483937704e-06
# Testing layer multi_layer for density and chlorides
# Got metric value 0.00889594790147985
# Testing layer multi_layer for density and free sulfur dioxide
# Got metric value 0.006596958230363992
# Testing layer multi_layer for density and total sulfur dioxide
# Got metric value 0.007039516829197567
# Testing layer multi_layer for density and density
# Got metric value 0.021473128314656975
# Testing layer multi_layer for density and pH
# Got metric value 0.005809277752093389
# Testing layer multi_layer for density and sulphates
# Got metric value 0.0007692730781930779
# Testing layer multi_layer for density and alcohol
# Got metric value 0.027491456262296432
# Testing layer multi_layer for pH and fixed acidity
# Got metric value 0.0075848092083694585
# Testing layer multi_layer for pH and volatile acidity
# Got metric value 0.0013797306535059395
# Testing layer multi_layer for pH and citric acid
# Got metric value 0.005230693772427131
# Testing layer multi_layer for pH and residual sugar
# Got metric value 0.002420070242721506
# Testing layer multi_layer for pH and chlorides
# Got metric value 0.0050427313722331
# Testing layer multi_layer for pH and free sulfur dioxide
# Got metric value 0.011932745513337228
# Testing layer multi_layer for pH and total sulfur dioxide
# Got metric value 0.01923263725788249
# Testing layer multi_layer for pH and density
# Got metric value 0.005809273395694259
# Testing layer multi_layer for pH and pH
# Got metric value 7.143079592974999e-05
# Testing layer multi_layer for pH and sulphates
# Got metric value 0.002583267131174294
# Testing layer multi_layer for pH and alcohol
# Got metric value 9.859535106016004e-06
# Testing layer multi_layer for sulphates and fixed acidity
# Got metric value 0.0028694466536213215
# Testing layer multi_layer for sulphates and volatile acidity
# Got metric value 3.994034309817707e-05
# Testing layer multi_layer for sulphates and citric acid
# Got metric value 0.0003770952996172694
# Testing layer multi_layer for sulphates and residual sugar
# Got metric value 0.00017943106619766613
# Testing layer multi_layer for sulphates and chlorides
# Got metric value 0.008681472370863919
# Testing layer multi_layer for sulphates and free sulfur dioxide
# Got metric value 0.004987619223993711
# Testing layer multi_layer for sulphates and total sulfur dioxide
# Got metric value 0.009711841062409854
# Testing layer multi_layer for sulphates and density
# Got metric value 0.0007692474392483328
# Testing layer multi_layer for sulphates and pH
# Got metric value 0.002583267464399852
# Testing layer multi_layer for sulphates and sulphates
# Got metric value 0.0011456978007189367
# Testing layer multi_layer for sulphates and alcohol
# Got metric value 0.009562754366932213
# Testing layer multi_layer for alcohol and fixed acidity
# Got metric value 0.0015953551945058209
# Testing layer multi_layer for alcohol and volatile acidity
# Got metric value 0.023034690825775583
# Testing layer multi_layer for alcohol and citric acid
# Got metric value 0.012444136446969734
# Testing layer multi_layer for alcohol and residual sugar
# Got metric value 0.0009187675197320777
# Testing layer multi_layer for alcohol and chlorides
# Got metric value 0.001321565748015896
# Testing layer multi_layer for alcohol and free sulfur dioxide
# Got metric value 0.0018188948462275478
# Testing layer multi_layer for alcohol and total sulfur dioxide
# Got metric value 0.001973010918826401
# Testing layer multi_layer for alcohol and density
# Got metric value 0.02749149936747841
# Testing layer multi_layer for alcohol and pH
# Got metric value -0.00010643626978468212
# Testing layer multi_layer for alcohol and sulphates
# Got metric value 0.009562756981470799
# Testing layer multi_layer for alcohol and alcohol
# Got metric value 0.05835666069146994
# Done layer 1
#
# New model:
#
# Y = 1*(-0.16) + 1*(0.16) * (alcohol) * (alcohol)
#
# New best score 0.05835666069146994
#
# New score on Test 0.0497600762182393
#
# -------------------------------------------------------------------------------------------------------------------------------
# Testing layer multi_layer for fixed acidity and fixed acidity
# Got metric value 0.06276820908983494
# Testing layer multi_layer for fixed acidity and volatile acidity
# Got metric value 0.06053030278978133
# Testing layer multi_layer for fixed acidity and citric acid
# Got metric value 0.06675277013142578
# Testing layer multi_layer for fixed acidity and residual sugar
# Got metric value 0.058877488144989054
# Testing layer multi_layer for fixed acidity and chlorides
# Got metric value 0.06024341102123376
# Testing layer multi_layer for fixed acidity and free sulfur dioxide
# Got metric value 0.06595668653413478
# Testing layer multi_layer for fixed acidity and total sulfur dioxide
# Got metric value 0.07088347069119483
# Testing layer multi_layer for fixed acidity and density
# Got metric value 0.061288390446569085
# Testing layer multi_layer for fixed acidity and pH
# Got metric value 0.059569889162051415
# Testing layer multi_layer for fixed acidity and sulphates
# Got metric value 0.0629900839527272
# Testing layer multi_layer for fixed acidity and alcohol
# Got metric value 0.05848475777503204
# Testing layer multi_layer for fixed acidity and (0.16) * (alcohol) * (alcohol)
# Got metric value 0.05955584784972345
# Testing layer multi_layer for volatile acidity and fixed acidity
# Got metric value 0.060530307732298616
# Testing layer multi_layer for volatile acidity and volatile acidity
# Got metric value 0.07027932241982071
# Testing layer multi_layer for volatile acidity and citric acid
# Got metric value 0.058381367286737595
# Testing layer multi_layer for volatile acidity and residual sugar
# Got metric value 0.05858943315711673
# Testing layer multi_layer for volatile acidity and chlorides
# Got metric value 0.06013797856156988
# Testing layer multi_layer for volatile acidity and free sulfur dioxide
# Got metric value 0.06877045115640024
# Testing layer multi_layer for volatile acidity and total sulfur dioxide
# Got metric value 0.07286502526917871
# Testing layer multi_layer for volatile acidity and density
# Got metric value 0.0609680019713329
# Testing layer multi_layer for volatile acidity and pH
# Got metric value 0.059019435101048234
# Testing layer multi_layer for volatile acidity and sulphates
# Got metric value 0.058390778288045286
# Testing layer multi_layer for volatile acidity and alcohol
# Got metric value 0.06595935712917944
# Testing layer multi_layer for volatile acidity and (0.16) * (alcohol) * (alcohol)
# Got metric value 0.0877967208141156
# Testing layer multi_layer for citric acid and fixed acidity
# Got metric value 0.06675277515760136
# Testing layer multi_layer for citric acid and volatile acidity
# Got metric value 0.0583813565334248
# Testing layer multi_layer for citric acid and citric acid
# Got metric value 0.06194138722714415
# Testing layer multi_layer for citric acid and residual sugar
# Got metric value 0.05965563816121122
# Testing layer multi_layer for citric acid and chlorides
# Got metric value -0.0020139028385304236
# Testing layer multi_layer for citric acid and free sulfur dioxide
# Got metric value 0.07452555847573583
# Testing layer multi_layer for citric acid and total sulfur dioxide
# Got metric value 0.08587611586104604
# Testing layer multi_layer for citric acid and density
# Got metric value 0.05875626012230184
# Testing layer multi_layer for citric acid and pH
# Got metric value 0.0594397404374859
# Testing layer multi_layer for citric acid and sulphates
# Got metric value 0.058576264607942186
# Testing layer multi_layer for citric acid and alcohol
# Got metric value 0.06746229194397335
# Testing layer multi_layer for citric acid and (0.16) * (alcohol) * (alcohol)
# Got metric value 0.061987434603795855
# Testing layer multi_layer for residual sugar and fixed acidity
# Got metric value 0.058877487981653154
# Testing layer multi_layer for residual sugar and volatile acidity
# Got metric value 0.058589433250467615
# Testing layer multi_layer for residual sugar and citric acid
# Got metric value 0.05965563515947525
# Testing layer multi_layer for residual sugar and residual sugar
# Got metric value 0.05851664818117597
# Testing layer multi_layer for residual sugar and chlorides
# Got metric value 0.058516179814216085
# Testing layer multi_layer for residual sugar and free sulfur dioxide
# Got metric value 0.05970232808302944
# Testing layer multi_layer for residual sugar and total sulfur dioxide
# Got metric value 0.05850775229607741
# Testing layer multi_layer for residual sugar and density
# Got metric value 0.058653111115877565
# Testing layer multi_layer for residual sugar and pH
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 48
#      45     print(f"Testing layer {layer.__name__} for {prev_layer.__str__()} and {second_layer.__str__()}")
#      47 step_model = RegressionModel(r2_score, lr, step_layers)
# ---> 48 train(step_model, x1, y1, epoch_num=1000, verbose=verbose)
#      49 step_score = step_model.get_metric(x1, y1)
#      50 if verbose2:
#
# Cell In[16], line 8, in train(model, X, Y, epoch_num, verbose)
#       6 Y_pred = model(X)
#       7 loss = criterion(Y_pred, Y.squeeze())
# ----> 8 loss.backward()
#       9 optimizer.step()
#      10 if verbose:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\autograd\__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
print('Final model: \n')
print(Model, '\n')
print(f'Train score {Model.get_metric(x1, y1)} \n')
print(f'Test score {Model.get_metric(x2, y2)} \n')

# %%
linear_model = LinearRegression()
linear_model.fit(X_train_norm, Y_train_norm)

# %%
predictions = linear_model.predict(X_test_norm)
r2_score(Y_test_norm, predictions)

# %%
predictions = linear_model.predict(X_train_norm)
r2_score(Y_train_norm, predictions)
